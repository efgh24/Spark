# %% [markdown]
# # Dataquest - Jupyter Notebook Guided Project
#
# The Jupyter Notebook will Analyze data about mobile apps available on Google Play and the App Store. As of September 2018, there were approximately 2 million iOS apps available on the App Store, and 2.1 million Android apps on Google Play.
#
# The data will be a sample of the following:
# - 10,000 Android apps from Google Play; the data was collected in August 2018
# - 7,000 iOS apps from the App Store; the data was collected in July 2017

# %%
def open_dataset(file_name='AppleStore.csv', header = True):
    opened_file = open(file_name)
    from csv import reader
    read_file = reader(opened_file)
    data = list(read_file)
    if header:
        return data
    return data[1:]

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line between rows
        
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
ios = open_dataset()
ios[0:2]
# Out:
# [['id',
#   'track_name',
#   'size_bytes',
#   'currency',
#   'price',
#   'rating_count_tot',
#   'rating_count_ver',
#   'user_rating',
#   'user_rating_ver',
#   'ver',
#   'cont_rating',
#   'prime_genre',
#   'sup_devices.num',
#   'ipadSc_urls.num',
#   'lang.num',
#   'vpp_lic'],
#  ['284882215',
#   'Facebook',
#   '389879808',
#   'USD',
#   '0.0',
#   '2974676',
#   '212',
#   '3.5',
#   '3.5',
#   '95.0',
#   '4+',
#   'Social Networking',
#   '37',
#   '1',
#   '29',
#   '1']]

# %%
Android = open_dataset(file_name='googleplaystore.csv', header = True)
Android[0:2]
# Out:
# [['App',
#   'Category',
#   'Rating',
#   'Reviews',
#   'Size',
#   'Installs',
#   'Type',
#   'Price',
#   'Content Rating',
#   'Genres',
#   'Last Updated',
#   'Current Ver',
#   'Android Ver'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'ART_AND_DESIGN',
#   '4.1',
#   '159',
#   '19M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 7, 2018',
#   '1.0.0',
#   '4.0.3 and up']]

# %%
explore_data(Apple, 1, 5)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']

# %%
explore_data(Android, 1, 5)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']

# %%
len(Android)
# Out:
# 10842

# %%
explore_data(Android, 10470, 10480)
# Out:
# ['TownWiFi | Wi-Fi Everywhere', 'COMMUNICATION', '3.9', '2372', '58M', '500,000+', 'Free', '0', 'Everyone', 'Communication', 'August 2, 2018', '4.2.1', '4.2 and up']
#
#
# ['Jazz Wi-Fi', 'COMMUNICATION', '3.4', '49', '4.0M', '10,000+', 'Free', '0', 'Everyone', 'Communication', 'February 10, 2017', '0.1', '2.3 and up']
#
#
# ['Xposed Wi-Fi-Pwd', 'PERSONALIZATION', '3.5', '1042', '404k', '100,000+', 'Free', '0', 'Everyone', 'Personalization', 'August 5, 2014', '3.0.0', '4.0.3 and up']
#
#
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
#
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']
#
#
# ['Sat-Fi Voice', 'COMMUNICATION', '3.4', '37', '14M', '1,000+', 'Free', '0', 'Everyone', 'Communication', 'November 21, 2014', '2.2.1.5', '2.2 and up']
#
#
# ...

# %%
d_cat = {}
d_app = {}
i = 1

for row in Android:
    cat = row[1]
    app = row[0]
    if cat not in d_cat:
        d_cat[cat] = 1
    else:
        d_cat[cat] += 1
    if app not in d_app:
        d_app[app] = 1
    else:
        d_app[app] += 1

# %%
d_cat
# Out:
# {'Category': 1,
#  'ART_AND_DESIGN': 65,
#  'AUTO_AND_VEHICLES': 85,
#  'BEAUTY': 53,
#  'BOOKS_AND_REFERENCE': 231,
#  'BUSINESS': 460,
#  'COMICS': 60,
#  'COMMUNICATION': 387,
#  'DATING': 234,
#  'EDUCATION': 156,
#  'ENTERTAINMENT': 149,
#  'EVENTS': 64,
#  'FINANCE': 366,
#  'FOOD_AND_DRINK': 127,
#  'HEALTH_AND_FITNESS': 341,
#  'HOUSE_AND_HOME': 88,
#  'LIBRARIES_AND_DEMO': 85,
#  'LIFESTYLE': 382,
#  'GAME': 1144,
#  'FAMILY': 1972,
#  'MEDICAL': 463,
#  'SOCIAL': 295,
#  'SHOPPING': 260,
#  'PHOTOGRAPHY': 335,
#  'SPORTS': 384,
#  'TRAVEL_AND_LOCAL': 258,
#  'TOOLS': 843,
#  'PERSONALIZATION': 392,
#  'PRODUCTIVITY': 424,
#  'PARENTING': 60,
#  'WEATHER': 82,
#  'VIDEO_PLAYERS': 175,
#  'NEWS_AND_MAGAZINES': 283,
#  'MAPS_AND_NAVIGATION': 137,
#  '1.9': 1}

# %%
d_app
# Out:
# {'App': 1,
#  'Photo Editor & Candy Camera & Grid & ScrapBook': 1,
#  'Coloring book moana': 2,
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps': 1,
#  'Sketch - Draw & Paint': 1,
#  'Pixel Draw - Number Art Coloring Book': 1,
#  'Paper flowers instructions': 1,
#  'Smoke Effect Photo Maker - Smoke Editor': 1,
#  'Infinite Painter': 1,
#  'Garden Coloring Book': 1,
#  'Kids Paint Free - Drawing Fun': 1,
#  'Text on Photo - Fonteee': 1,
#  'Name Art Photo Editor - Focus n Filters': 1,
#  'Tattoo Name On My Photo Editor': 1,
#  'Mandala Coloring Book': 1,
#  '3D Color Pixel by Number - Sandbox Art Coloring': 1,
#  'Learn To Draw Kawaii Characters': 1,
#  'Photo Designer - Write your name with shapes': 1,
#  '350 Diy Room Decor Ideas': 1,
#  'FlipaClip - Cartoon animation': 1,
#  'ibis Paint X': 1,
#  'Logo Maker - Small Business': 1,
#  "Boys Photo Editor - Six Pack & Men's Suit": 1,
#  'Superheroes Wallpapers | 4K Backgrounds': 1,
#  'Mcqueen Coloring pages': 2,
# ...

# %% [markdown]
# ## Removing Duplicate and Erroneous Data
#
# 1. Checking Category column for numerical data
# 2. Duplicate Data
#     - Checking for Duplicates:
#         1. Length of List (10841) vs Length of Set List (9660)
#         2. Hash list removal of duplicates (10358)
#         3. Remove the rest of the duplicates by the larger of rating
#         4. Remove
#
#
# 1. Removed inaccurate data
# 2. Removed duplicate app entries
# 3. Removed non-English apps
# 4. Isolated the free apps

# %%
i = 1
d_cat_check = {}
for row in Android[1:]:
    try:
        if float(row[1]):
            d_cat_check[i] = row[1]
    except ValueError:
        pass
    i += 1
d_cat_check
# Out:
# {10473: '1.9'}

# %%
Android[10473]
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame',
#  '1.9',
#  '19',
#  '3.0M',
#  '1,000+',
#  'Free',
#  '0',
#  'Everyone',
#  '',
#  'February 11, 2018',
#  '1.0.19',
#  '4.0 and up']

# %%
del Android[10473]  # don't run this more than once

# %%
app_name = []
for row in Android[1:]:
    appname = row[0]
    app_name.append(appname)

# %%
print(len(app_name),len(set(app_name)))
# Out:
# 10840 9659

# %%
i = 1
d_app_list = []
d_app_check = {}
d_app_dupe = {}
for row in Android[1:]:
    app = row[0]
    if app not in d_app_list:
        d_app_list.append(app)
        d_app_check[i] = app
    else:
        d_app_dupe[i] = app
    i += 1
d_app_check
# Out:
# {1: 'Photo Editor & Candy Camera & Grid & ScrapBook',
#  2: 'Coloring book moana',
#  3: 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#  4: 'Sketch - Draw & Paint',
#  5: 'Pixel Draw - Number Art Coloring Book',
#  6: 'Paper flowers instructions',
#  7: 'Smoke Effect Photo Maker - Smoke Editor',
#  8: 'Infinite Painter',
#  9: 'Garden Coloring Book',
#  10: 'Kids Paint Free - Drawing Fun',
#  11: 'Text on Photo - Fonteee',
#  12: 'Name Art Photo Editor - Focus n Filters',
#  13: 'Tattoo Name On My Photo Editor',
#  14: 'Mandala Coloring Book',
#  15: '3D Color Pixel by Number - Sandbox Art Coloring',
#  16: 'Learn To Draw Kawaii Characters',
#  17: 'Photo Designer - Write your name with shapes',
#  18: '350 Diy Room Decor Ideas',
#  19: 'FlipaClip - Cartoon animation',
#  20: 'ibis Paint X',
#  21: 'Logo Maker - Small Business',
#  22: "Boys Photo Editor - Six Pack & Men's Suit",
#  23: 'Superheroes Wallpapers | 4K Backgrounds',
#  24: 'Mcqueen Coloring pages',
# ...

# %%
d_app_dupe
# Out:
# {230: 'Quick PDF Scanner + OCR FREE',
#  237: 'Box',
#  240: 'Google My Business',
#  257: 'ZOOM Cloud Meetings',
#  262: 'join.me - Simple Meetings',
#  266: 'Box',
#  267: 'Zenefits',
#  268: 'Google Ads',
#  269: 'Google My Business',
#  270: 'Slack',
#  271: 'FreshBooks Classic',
#  272: 'Insightly CRM',
#  273: 'QuickBooks Accounting: Invoicing & Expenses',
#  274: 'HipChat - Chat Built for Teams',
#  275: 'Xero Accounting Software',
#  276: 'MailChimp - Email, Marketing Automation',
#  277: 'Crew - Free Messaging and Scheduling',
#  278: 'Asana: organize team projects',
#  279: 'Google Analytics',
#  280: 'AdWords Express',
#  281: 'Accounting App - Zoho Books',
#  282: 'Invoice & Time Tracking - Zoho',
#  283: 'join.me - Simple Meetings',
#  284: 'Invoice 2go — Professional Invoices and Estimates',
#  285: 'SignEasy | Sign and Fill PDF and other Documents',
#  286: 'Quick PDF Scanner + OCR FREE',
#  287: 'Genius Scan - PDF Scanner',
#  288: 'Tiny Scanner - PDF Scanner App',
# ...

# %%
explore_data(Android, 223, 231)
# Out:
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
#
#
# ['sABN', 'BUSINESS', '4.4', '2287', '1.5M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'March 26, 2018', '4.9', '2.2 and up']
#
#
# ['ATI Cargoes and Transportation', 'BUSINESS', '4.7', '4162', '7.5M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '0.9.4', '4.0.3 and up']
#
#
# ['Secure Folder', 'BUSINESS', '3.8', '14760', '8.6M', '50,000,000+', 'Free', '0', 'Everyone', 'Business', 'January 31, 2018', '1.1.07.6', '7.0 and up']
#
#
# ['UPS Mobile', 'BUSINESS', '3.9', '23243', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'June 25, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Y! Mobile menu', 'BUSINESS', 'NaN', '9', '1.2M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'April 9, 2018', '1.0.5', '6.0 and up']
#
#
# ...

# %%
s = Android[194]

t = ''.join(s)

print(hash(t))

# %%
d_hash = {}
lst = []
n_Android = []
i = 1
for row in Android[1:]:
    arr_string = ''.join(row)
    hasher = hash(arr_string)
    if hasher not in lst:
        lst.append(hasher)
        n_Android.append(row)

# %%
len(n_Android)
# Out:
# 10357

# %%
j = 0
d_app_list_2 = []
d_app_check_2 = {}
d_app_dupe_2 = {}
for row in n_Android[0:]:
    app = row[0]
    if app not in d_app_list_2:
        d_app_list_2.append(app)
        d_app_check_2[j] = app
    else:
        d_app_dupe_2[j] = app
    j += 1
d_app_check_2
# Out:
# {0: 'Photo Editor & Candy Camera & Grid & ScrapBook',
#  1: 'Coloring book moana',
#  2: 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#  3: 'Sketch - Draw & Paint',
#  4: 'Pixel Draw - Number Art Coloring Book',
#  5: 'Paper flowers instructions',
#  6: 'Smoke Effect Photo Maker - Smoke Editor',
#  7: 'Infinite Painter',
#  8: 'Garden Coloring Book',
#  9: 'Kids Paint Free - Drawing Fun',
#  10: 'Text on Photo - Fonteee',
#  11: 'Name Art Photo Editor - Focus n Filters',
#  12: 'Tattoo Name On My Photo Editor',
#  13: 'Mandala Coloring Book',
#  14: '3D Color Pixel by Number - Sandbox Art Coloring',
#  15: 'Learn To Draw Kawaii Characters',
#  16: 'Photo Designer - Write your name with shapes',
#  17: '350 Diy Room Decor Ideas',
#  18: 'FlipaClip - Cartoon animation',
#  19: 'ibis Paint X',
#  20: 'Logo Maker - Small Business',
#  21: "Boys Photo Editor - Six Pack & Men's Suit",
#  22: 'Superheroes Wallpapers | 4K Backgrounds',
#  23: 'Mcqueen Coloring pages',
# ...

# %%
d_app_dupe_2
# Out:
# {260: 'Quick PDF Scanner + OCR FREE',
#  261: 'OfficeSuite : Free Office + PDF Editor',
#  262: 'Slack',
#  348: 'Messenger – Text and Video Chat for Free',
#  349: 'imo free video calls and chat',
#  351: 'Viber Messenger',
#  352: 'Hangouts',
#  356: 'WeChat',
#  358: 'Telegram',
#  359: 'Who',
#  372: 'Firefox Focus: The privacy browser',
#  374: 'Google Allo',
#  375: 'Google Chrome: Fast & Secure',
#  376: 'Firefox Browser fast & private',
#  378: 'Opera Browser: Fast and Secure',
#  380: 'Opera Mini - fast web browser',
#  382: 'UC Browser Mini -Tiny Fast Private & Secure',
#  383: 'UC Browser - Fast Download Private & Secure',
#  397: 'Call Blocker',
#  412: 'Gmail',
#  413: 'Yahoo Mail – Stay Organized',
#  425: 'Hangouts',
#  426: 'Viber Messenger',
#  500: 'Cougar Dating Life : Date Older Women Sugar Mummy',
#  501: 'stranger chat - anonymous chat',
#  502: 'Millionaire Match: Rich Singles Dating App',
#  504: 'Dating for 50 plus Mature Singles – FINALLY',
# ...

# %%
n_Android[222]
# Out:
# ['Quick PDF Scanner + OCR FREE',
#  'BUSINESS',
#  '4.2',
#  '80805',
#  'Varies with device',
#  '5,000,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'Business',
#  'February 26, 2018',
#  'Varies with device',
#  '4.0.3 and up']

# %%
n_Android[260]
# Out:
# ['Quick PDF Scanner + OCR FREE',
#  'BUSINESS',
#  '4.2',
#  '80804',
#  'Varies with device',
#  '5,000,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'Business',
#  'February 26, 2018',
#  'Varies with device',
#  '4.0.3 and up']

# %%
n_Android[194]
# Out:
# ['OfficeSuite : Free Office + PDF Editor',
#  'BUSINESS',
#  '4.3',
#  '1002861',
#  '35M',
#  '100,000,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'Business',
#  'August 2, 2018',
#  '9.7.14188',
#  '4.1 and up']

# %%
n_Android[261]
# Out:
# ['OfficeSuite : Free Office + PDF Editor',
#  'BUSINESS',
#  '4.3',
#  '1002859',
#  '35M',
#  '100,000,000+',
#  'Free',
#  '0',
#  'Everyone',
#  'Business',
#  'August 2, 2018',
#  '9.7.14188',
#  '4.1 and up']

# %%
explore_data(n_Android, 222, 261)
# Out:
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
#
#
# ['sABN', 'BUSINESS', '4.4', '2287', '1.5M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'March 26, 2018', '4.9', '2.2 and up']
#
#
# ['ATI Cargoes and Transportation', 'BUSINESS', '4.7', '4162', '7.5M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '0.9.4', '4.0.3 and up']
#
#
# ['Secure Folder', 'BUSINESS', '3.8', '14760', '8.6M', '50,000,000+', 'Free', '0', 'Everyone', 'Business', 'January 31, 2018', '1.1.07.6', '7.0 and up']
#
#
# ['UPS Mobile', 'BUSINESS', '3.9', '23243', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'June 25, 2018', 'Varies with device', 'Varies with device']
#
#
# ['Y! Mobile menu', 'BUSINESS', 'NaN', '9', '1.2M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'April 9, 2018', '1.0.5', '6.0 and up']
#
#
# ...

# %%
reviews_max = {}

for app in n_Android:
    name = app[0]
    n_reviews = float(app[3])
    
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
        
    elif name not in reviews_max:
        reviews_max[name] = n_reviews

# %%
reviews_max
# Out:
# {'Photo Editor & Candy Camera & Grid & ScrapBook': 159.0,
#  'Coloring book moana': 974.0,
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps': 87510.0,
#  'Sketch - Draw & Paint': 215644.0,
#  'Pixel Draw - Number Art Coloring Book': 967.0,
#  'Paper flowers instructions': 167.0,
#  'Smoke Effect Photo Maker - Smoke Editor': 178.0,
#  'Infinite Painter': 36815.0,
#  'Garden Coloring Book': 13791.0,
#  'Kids Paint Free - Drawing Fun': 121.0,
#  'Text on Photo - Fonteee': 13880.0,
#  'Name Art Photo Editor - Focus n Filters': 8788.0,
#  'Tattoo Name On My Photo Editor': 44829.0,
#  'Mandala Coloring Book': 4326.0,
#  '3D Color Pixel by Number - Sandbox Art Coloring': 1518.0,
#  'Learn To Draw Kawaii Characters': 55.0,
#  'Photo Designer - Write your name with shapes': 3632.0,
#  '350 Diy Room Decor Ideas': 27.0,
#  'FlipaClip - Cartoon animation': 194216.0,
#  'ibis Paint X': 224399.0,
#  'Logo Maker - Small Business': 450.0,
#  "Boys Photo Editor - Six Pack & Men's Suit": 654.0,
# ...

# %%
android_clean = []
already_added = []

for app in n_Android:
    name = app[0]
    n_reviews = float(app[3])
    
    if (reviews_max[name] == n_reviews) and (name not in already_added):
        android_clean.append(app)
        already_added.append(name) # make sure this is inside the if block

# %%
len(android_clean)
# Out:
# 9659

# %%
d_noeng = {}
i = 0

for row in android_clean:
    name = row[0]
    if ord(name[0]) > 127:
        d_noeng[i] = name
    i += 1
d_noeng
# Out:
# {259: '漫咖 Comics - Manga,Novel and Stories',
#  266: '【Ranobbe complete free】 Novelba - Free app that you can read and write novels',
#  651: '🔥 Football Wallpapers 4K | Full HD Backgrounds 😍',
#  789: 'İşCep',
#  1111: '乐屋网: Buying a house, selling a house, renting a house',
#  1206: 'သိင်္ Astrology - Min Thein Kha BayDin',
#  1900: '💘 WhatsLov: Smileys of love, stickers and GIF',
#  2834: 'РИА Новости',
#  2886: '乗換NAVITIME\u3000Timetable & Route Search in Japan Tokyo',
#  2921: 'ÖBB Scotty',
#  2991: '► MultiCraft ― Free Miner! 👍',
#  3168: 'صور حرف H',
#  3313: "💎 I'm rich",
#  4412: '中国語 AQリスニング',
#  4463: '【Miku AR Camera】Mikuture',
#  4586: '日本AV历史',
#  4717: '¡Ay Caramba!',
#  4729: '¡Ay Metro!',
#  4885: 'বাংলা টিভি প্রো BD Bangla TV',
#  5205: '뽕티비 - 개인방송, 인터넷방송, BJ방송',
#  5289: 'あなカレ【BL】無料ゲーム',
#  5291: '감성학원 BL 첫사랑',
#  6031: 'Билеты ПДД CD 2019 PRO',
#  6035: 'РееI Smart Remote MP3 CD Player',
#  6402: '📏 Smart Ruler ↔️ cm/inch measuring for homework!',
# ...

# %%
d_noeng
remove = [266, 651, 1900, 2991, 3313, 4463, 6035, 6402, 6658]
for i in remove:
    del d_noeng[i]
d_noeng
# Out:
# {259: '漫咖 Comics - Manga,Novel and Stories',
#  789: 'İşCep',
#  1111: '乐屋网: Buying a house, selling a house, renting a house',
#  1206: 'သိင်္ Astrology - Min Thein Kha BayDin',
#  2834: 'РИА Новости',
#  2886: '乗換NAVITIME\u3000Timetable & Route Search in Japan Tokyo',
#  2921: 'ÖBB Scotty',
#  3168: 'صور حرف H',
#  4412: '中国語 AQリスニング',
#  4586: '日本AV历史',
#  4717: '¡Ay Caramba!',
#  4729: '¡Ay Metro!',
#  4885: 'বাংলা টিভি প্রো BD Bangla TV',
#  5205: '뽕티비 - 개인방송, 인터넷방송, BJ방송',
#  5289: 'あなカレ【BL】無料ゲーム',
#  5291: '감성학원 BL 첫사랑',
#  6031: 'Билеты ПДД CD 2019 PRO',
#  6591: 'الفاتحون Conquerors',
#  6972: 'Šmelina .cz inzeráty inzerce',
#  7940: 'لعبة تقدر تربح DZ',
#  8023: 'বাংলাflix',
#  8045: '英漢字典 EC Dictionary',
#  8131: 'أحداث وحقائق | خبر عاجل في اخبار العالم',
#  8289: 'パーリーゲイツ公式通販｜EJ STYLE（イージェイスタイル）',
#  8642: '¿Es Vegan?',
#  8651: 'Égalité et Réconciliation',
#  8931: '哈哈姆特不EY'}

# %%
def is_english(string):
    non_ascii = 0
    
    for character in string:
        if ord(character) > 127:
            non_ascii += 1
    
    if non_ascii > 3:
        return False
    else:
        return True

# %%
android_english = []
ios_english = []

for app in android_clean:
    name = app[0]
    if is_english(name):
        android_english.append(app)
        
for app in ios:
    name = app[1]
    if is_english(name):
        ios_english.append(app)
        
explore_data(android_english, 0, 3, True)
print('\n')
explore_data(ios_english, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
# ...
