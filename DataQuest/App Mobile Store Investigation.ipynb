# %% [markdown]
# # Analysis of Mobile Apps
#
#
# As of September 2018, there were approximately 2 million iOS apps available on the App Store, and 2.1 million Android apps on Google Play. The goal is to analyze the application markets to see what apps would be good to build based on in-app ads. The most important indicator of app revenue is the number of users that use the app.
#
# The data will be a sample of the following:
# - 10,000 Android apps from Google Play; the data was collected in August 2018
# - 7,000 iOS apps from the App Store; the data was collected in July 2017

# %%
def open_dataset(file_name='AppleStore.csv', header = True):
    opened_file = open(file_name)
    from csv import reader
    read_file = reader(opened_file)
    data = list(read_file)
    if header:
        return data
    return data[1:]

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line between rows
        
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
ios = open_dataset()
ios[0:2]
# Out:
# [['id',
#   'track_name',
#   'size_bytes',
#   'currency',
#   'price',
#   'rating_count_tot',
#   'rating_count_ver',
#   'user_rating',
#   'user_rating_ver',
#   'ver',
#   'cont_rating',
#   'prime_genre',
#   'sup_devices.num',
#   'ipadSc_urls.num',
#   'lang.num',
#   'vpp_lic'],
#  ['284882215',
#   'Facebook',
#   '389879808',
#   'USD',
#   '0.0',
#   '2974676',
#   '212',
#   '3.5',
#   '3.5',
#   '95.0',
#   '4+',
#   'Social Networking',
#   '37',
#   '1',
#   '29',
#   '1']]

# %%
android = open_dataset(file_name='googleplaystore.csv', header = True)
android[0:2]
# Out:
# [['App',
#   'Category',
#   'Rating',
#   'Reviews',
#   'Size',
#   'Installs',
#   'Type',
#   'Price',
#   'Content Rating',
#   'Genres',
#   'Last Updated',
#   'Current Ver',
#   'Android Ver'],
#  ['Photo Editor & Candy Camera & Grid & ScrapBook',
#   'ART_AND_DESIGN',
#   '4.1',
#   '159',
#   '19M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'January 7, 2018',
#   '1.0.0',
#   '4.0.3 and up']]

# %%
explore_data(ios, 1, 5)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']

# %%
explore_data(android, 1, 5)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']

# %% [markdown]
# ## Removing Duplicate and Erroneous Data
#
# 1. Remove inaccurate data
# 2. Remove duplicate app entries
# 3. Removed non-English apps
# 4. Isolated the free apps

# %% [markdown]
# ## 1. Remove inaccurate data
#
# Go through the data and see if there are any rows that are any columns with inaccurate data. The Category column of the Android data set is comprised of String data if any column contains integers remove it the data.

# %%
d_cat = {}
d_app = {}
i = 1

for row in android[1:]:
    cat = row[1]
    app = row[0]
    if cat not in d_cat:
        d_cat[cat] = 1
    else:
        d_cat[cat] += 1
    if app not in d_app:
        d_app[app] = 1
    else:
        d_app[app] += 1

# %%
d_cat
# Out:
# {'ART_AND_DESIGN': 65,
#  'AUTO_AND_VEHICLES': 85,
#  'BEAUTY': 53,
#  'BOOKS_AND_REFERENCE': 231,
#  'BUSINESS': 460,
#  'COMICS': 60,
#  'COMMUNICATION': 387,
#  'DATING': 234,
#  'EDUCATION': 156,
#  'ENTERTAINMENT': 149,
#  'EVENTS': 64,
#  'FINANCE': 366,
#  'FOOD_AND_DRINK': 127,
#  'HEALTH_AND_FITNESS': 341,
#  'HOUSE_AND_HOME': 88,
#  'LIBRARIES_AND_DEMO': 85,
#  'LIFESTYLE': 382,
#  'GAME': 1144,
#  'FAMILY': 1972,
#  'MEDICAL': 463,
#  'SOCIAL': 295,
#  'SHOPPING': 260,
#  'PHOTOGRAPHY': 335,
#  'SPORTS': 384,
#  'TRAVEL_AND_LOCAL': 258,
#  'TOOLS': 843,
#  'PERSONALIZATION': 392,
#  'PRODUCTIVITY': 424,
#  'PARENTING': 60,
#  'WEATHER': 82,
#  'VIDEO_PLAYERS': 175,
#  'NEWS_AND_MAGAZINES': 283,
#  'MAPS_AND_NAVIGATION': 137,
#  '1.9': 1}

# %%
i = 1
d_cat_check = {}
for row in android[1:]:
    try:
        if float(row[1]):
            d_cat_check[i] = row[1]
    except ValueError:
        pass
    i += 1
d_cat_check
# Out:
# {10473: '1.9'}

# %%
del android[10473]  # don't run this more than once

# %% [markdown]
# ## 2. Remove duplicate app entries
#
# The data contains duplicate rows of data as well as rows where there are slight differences in the number of reviews.

# %%
i = 1
d_app_list = []
d_app_check = {}
d_app_dupe = {}
for row in android[1:]:
    app = row[0]
    if app not in d_app_list:
        d_app_list.append(app)
        d_app_check[i] = app
    else:
        d_app_dupe[i] = app
    i += 1
d_app_check
# Out:
# {1: 'Photo Editor & Candy Camera & Grid & ScrapBook',
#  2: 'Coloring book moana',
#  3: 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#  4: 'Sketch - Draw & Paint',
#  5: 'Pixel Draw - Number Art Coloring Book',
#  6: 'Paper flowers instructions',
#  7: 'Smoke Effect Photo Maker - Smoke Editor',
#  8: 'Infinite Painter',
#  9: 'Garden Coloring Book',
#  10: 'Kids Paint Free - Drawing Fun',
#  11: 'Text on Photo - Fonteee',
#  12: 'Name Art Photo Editor - Focus n Filters',
#  13: 'Tattoo Name On My Photo Editor',
#  14: 'Mandala Coloring Book',
#  15: '3D Color Pixel by Number - Sandbox Art Coloring',
#  16: 'Learn To Draw Kawaii Characters',
#  17: 'Photo Designer - Write your name with shapes',
#  18: '350 Diy Room Decor Ideas',
#  19: 'FlipaClip - Cartoon animation',
#  20: 'ibis Paint X',
#  21: 'Logo Maker - Small Business',
#  22: "Boys Photo Editor - Six Pack & Men's Suit",
#  23: 'Superheroes Wallpapers | 4K Backgrounds',
#  24: 'Mcqueen Coloring pages',
#  25: 'HD Mickey Minnie Wallpapers',
#  26: 'Harley Quinn wallpapers HD',
#  27: 'Colorfit - Drawing & Coloring',
#  28: 'Animated Photo Editor',
#  29: 'Pencil Sketch Drawing',
#  30: 'Easy Realistic Drawing Tutorial',
#  31: 'Pink Silver Bow Keyboard Theme',
#  32: 'Art Drawing Ideas',
#  33: 'Anime Manga Coloring Book',
#  34: 'Easy Origami Ideas',
#  35: 'I Creative Idea',
#  36: 'How to draw Ladybug and Cat Noir',
#  37: 'UNICORN - Color By Number & Pixel Art Coloring',
#  38: 'Floor Plan Creator',
#  39: 'PIP Camera - PIP Collage Maker',
#  40: 'How To Color Disney Princess - Coloring Pages',
#  41: 'Drawing Clothes Fashion Ideas',
#  42: 'Sad Poetry Photo Frames 2018',
#  43: 'Textgram - write on photos',
#  44: 'Paint Splash!',
#  45: 'Popsicle Sticks and Similar DIY Craft Ideas',
#  46: 'Canva: Poster, banner, card maker & graphic design',
#  47: 'Install images with music to make video without Net - 2018',
#  48: 'Little Teddy Bear Colouring Book Game',
#  49: 'How To Draw Food',
#  50: 'Monster Truck Stunt 3D 2019',
#  51: 'Real Tractor Farming',
#  52: 'Ultimate F1 Racing Championship',
#  53: 'Used Cars and Trucks for Sale',
#  54: 'American Muscle Car Race',
#  55: 'Offroad Oil Tanker Driver Transport Truck 2019',
#  56: 'Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru',
#  57: 'Gas Prices (Germany only)',
#  58: 'Extreme Rally Championship',
#  59: 'Restart Navigator',
#  60: 'REG - Check the regnumber, find information about Swedish vehicles',
#  61: 'CityBus Lviv',
#  62: 'CDL Practice Test 2018 Edition',
#  63: 'ezETC (ETC balance inquiry, meter trial, real-time traffic)',
#  64: 'Free VIN Report for Used Cars',
#  65: 'DMV Permit Practice Test 2018 Edition',
#  66: 'Check Vehicle Tax',
#  67: 'Used Cars Mexico',
#  68: 'Ulysse Speedometer',
#  69: 'REPUVE',
#  70: 'Used cars for sale - Trovit',
#  71: 'Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines',
#  72: 'SK Enca Direct Malls - Used Cars Search',
#  73: 'Android Auto - Maps, Media, Messaging & Voice',
#  74: 'PDD-UA',
#  75: 'Tickets SDA 2019 + Exam RF',
#  76: 'Super Cars Wallpapers And Backgrounds',
#  77: 'Police Lights, Sirens & Follow Me',
#  78: 'Police Detector (Speed Camera Radar)',
#  79: 'Best Car Wallpapers',
#  80: 'Tickets + PDA 2018 Exam',
#  81: 'Pick Your Part Garage',
#  82: 'PakWheels: Buy & Sell Cars',
#  83: 'Supervision service',
#  84: 'Speed Camera Detector - Traffic & Speed Alert',
#  85: 'Used car search Goo net whole car Go to net',
#  86: 'CarMax – Cars for Sale: Search Used Car Inventory',
#  87: 'BEST CAR SOUNDS',
#  88: 'RST - Sale of cars on the PCT',
#  89: 'AutoScout24 Switzerland – Find your new car',
#  90: 'Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo',
#  91: 'SMS Park',
#  92: 'SKencar',
#  93: 'Fuelio: Gas log & costs',
#  94: 'auto fines',
#  95: 'Used car is the first car - used car purchase, used car quotation, dealer information to',
#  96: 'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)',
#  97: 'Inquiry Fines and Debits of Vehicles',
#  98: 'Gas Station',
#  99: 'Hush - Beauty for Everyone',
#  100: 'ipsy: Makeup, Beauty, and Tips',
#  101: 'Natural recipes for your beauty',
#  102: 'BestCam Selfie-selfie, beauty camera, photo editor',
#  103: 'Mirror - Zoom & Exposure -',
#  104: 'Beauty Selfie Camera',
#  105: 'Hairstyles step by step',
#  106: 'Filters for Selfie',
#  107: 'Tie - Always be happy',
#  108: 'Ulta Beauty',
#  109: 'Prom MakeUp Tutorial',
#  110: 'Selfie Camera',
#  111: 'Sweet Selfie Beauty Camera',
#  112: 'Colors of white in Urdu',
#  113: 'Selfie Camera Photo Editor & Filter & Sticker',
#  114: 'Wrinkles and rejuvenation',
#  115: 'Eyes Makeup Beauty Tips',
#  116: 'Photo Editor 2018',
#  117: 'Step By Step Eyes Makeup Tutorial',
#  118: 'Beauty Camera - Selfie Camera',
#  119: 'Girls Hairstyles',
#  120: 'Mirror Camera (Mirror + Selfie Camera)',
#  121: 'Beauty Tips - Beauty Tips in Sinhala',
#  122: 'Haircut Tutorials/Haircut Videos',
#  123: 'Sephora: Skin Care, Beauty Makeup & Fragrance Shop',
#  124: 'Manicure - nail design',
#  125: 'Sticker Camera - Selfie Filters, Beauty Camera',
#  126: 'Filters for B Live',
#  127: 'Skin Care and Natural Beauty',
#  128: 'Facial Wrinkle Reduction',
#  129: 'Makeup Videos',
#  130: 'Secrets of beauty, youth and health',
#  131: 'Recipes and tips for losing weight',
#  132: 'Discover Color',
#  133: 'Eyeliner step by step 2018',
#  134: 'Dresses Ideas & Fashions +3000',
#  135: 'Lady adviser (beauty, health)',
#  136: 'Step By Step Hairstyles For Women',
#  137: 'Rainbow Camera',
#  138: 'Methods of teeth whitening',
#  139: 'Girls hairstyles 2018',
#  140: 'Wattpad 📖 Free Books',
#  141: 'E-Book Read - Read Book for free',
#  142: 'Download free book with green book',
#  143: 'Wikipedia',
#  144: 'Amazon Kindle',
#  145: 'Cool Reader',
#  146: 'Dictionary - Merriam-Webster',
#  147: 'NOOK: Read eBooks & Magazines',
#  148: 'Free Panda Radio Music',
#  149: 'Book store',
#  150: 'FBReader: Favorite Book Reader',
#  151: 'English Grammar Complete Handbook',
#  152: 'Free Books - Spirit Fanfiction and Stories',
#  153: 'Google Play Books',
#  154: 'AlReader -any text book reader',
#  155: 'Offline English Dictionary',
#  156: 'Oxford Dictionary of English : Free',
#  157: 'Offline: English to Tagalog Dictionary',
#  158: 'Spanish English Translator',
#  159: 'FamilySearch Tree',
#  160: 'Cloud of Books',
#  161: 'Recipes of Prophetic Medicine for free',
#  162: 'ReadEra – free ebook reader',
#  163: 'NOOK App for NOOK Devices',
#  164: 'Anonymous caller detection',
#  165: 'Ebook Reader',
#  166: 'Litnet - E-books',
#  167: 'Read books online',
#  168: 'English to Urdu Dictionary',
#  169: 'eBoox: book reader fb2 epub zip',
#  170: 'English Persian Dictionary',
#  171: 'Flybook',
#  172: 'All Maths Formulas',
#  173: 'Ancestry',
#  174: 'HTC Help',
#  175: 'English translation from Bengali',
#  176: 'Pdf Book Download - Read Pdf Book',
#  177: 'Free Book Reader',
#  178: 'eBoox new: Reader for fb2 epub zip books',
#  179: 'Only 30 days in English, the guideline is guaranteed',
#  180: 'Moon+ Reader',
#  181: "SH-02J Owner's Manual (Android 8.0)",
#  182: 'English-Myanmar Dictionary',
#  183: 'Golden Dictionary (EN-AR)',
#  184: 'All Language Translator Free',
#  185: 'Azpen eReader',
#  186: 'URBANO V 02 instruction manual',
#  187: 'English Dictionary - Offline',
#  188: 'Visual Voicemail by MetroPCS',
#  189: 'Indeed Job Search',
#  190: 'Uber Driver',
#  191: 'ADP Mobile Solutions',
#  192: 'Snag - Jobs Hiring Now',
#  193: 'Docs To Go™ Free Office Suite',
#  194: 'Google My Business',
#  195: 'OfficeSuite : Free Office + PDF Editor',
#  196: 'USPS MOBILE®',
#  197: 'Job Search by ZipRecruiter',
#  198: 'Curriculum vitae App CV Builder Free Resume Maker',
#  199: 'Google Primer',
#  200: 'Alba Heaven - Alvarez Job Portal Services',
#  201: 'SuperLivePro',
#  202: 'Facebook Pages Manager',
#  203: 'OfficeSuite Pro + PDF (Trial)',
#  204: 'My Space - Employment Center',
#  205: 'Box',
#  206: 'Polaris Office for LG',
#  207: 'Call Blocker',
#  208: 'Jobs in Alabama - Jobs in Alba',
#  209: 'Square Point of Sale - POS',
#  210: 'Plugin:AOT v5.0',
#  211: 'Kariyer.net',
#  212: 'SEEK Job Search',
#  213: 'Become a Job - Find a job or advertise',
#  214: 'ZOOM Cloud Meetings',
#  215: 'Easy Installer - Apps On SD',
#  216: 'Facebook Ads Manager',
#  217: 'IndiaMART: Search Products, Buy, Sell & Trade',
#  218: 'ViettelPost express delivery',
#  219: 'MyASUS - Service Center',
#  220: 'Job Korea - Career Jobs',
#  221: '104 Looking for a job - looking for a job, looking for a job, looking for a part-time job, health checkup, resume, treatment room',
#  222: 'Myanmar 2D/3D',
#  223: 'Quick PDF Scanner + OCR FREE',
#  224: 'sABN',
#  225: 'ATI Cargoes and Transportation',
#  226: 'Secure Folder',
#  227: 'UPS Mobile',
#  228: 'Y! Mobile menu',
#  229: 'SignEasy | Sign and Fill PDF and other Documents',
#  231: 'Genius Scan - PDF Scanner',
#  232: 'Tiny Scanner - PDF Scanner App',
#  233: 'Fast Scanner : Free PDF Scan',
#  234: 'Mobile Doc Scanner (MDScan) Lite',
#  235: 'TurboScan: scan documents and receipts in PDF',
#  236: 'Tiny Scanner Pro: PDF Doc Scan',
#  238: 'Zenefits',
#  239: 'Google Ads',
#  241: 'Slack',
#  242: 'FreshBooks Classic',
#  243: 'Insightly CRM',
#  244: 'QuickBooks Accounting: Invoicing & Expenses',
#  245: 'HipChat - Chat Built for Teams',
#  246: 'Xero Accounting Software',
#  247: 'MailChimp - Email, Marketing Automation',
#  248: 'Crew - Free Messaging and Scheduling',
#  249: 'Asana: organize team projects',
#  250: 'Google Analytics',
#  251: 'AdWords Express',
#  252: 'Accounting App - Zoho Books',
#  253: 'Invoice & Time Tracking - Zoho',
#  254: 'join.me - Simple Meetings',
#  255: 'Invoice 2go — Professional Invoices and Estimates',
#  256: 'Cisco Webex Meetings',
#  258: 'ScreenMeet. Easy Phone Meeting',
#  259: 'Cisco Webex Teams',
#  260: 'Microsoft Remote Desktop',
#  261: 'Start Meeting',
#  263: 'ClickMeeting Webinars',
#  264: 'BlueJeans for Android',
#  265: 'Skype for Business for Android',
#  296: 'Verify - Receipts & Expenses',
#  298: 'LINE WEBTOON - Free Comics',
#  299: 'Manga Master - Best manga & comic reader',
#  300: 'GANMA! - All original stories free of charge for all original comics',
#  301: 'Röhrich Werner Soundboard',
#  302: 'Unicorn Pokez - Color By Number',
#  303: 'MangaToon - Comics updated Daily',
#  304: 'Manga Net – Best Online Manga Reader',
#  305: 'Manga Rock - Best Manga Reader',
#  306: 'Manga - read Thai translation',
#  307: 'The Vietnam Story - Fun Stories',
#  308: 'Dragon Ball Wallpaper - Ringtones',
#  309: 'Funny Jokes Photos',
#  310: 'Truyện Vui Tý Quậy',
#  311: 'Comic Es - Shojo manga / love comics free of charge ♪ ♪',
#  312: 'comico Popular Original Cartoon Updated Everyday Comico',
#  313: 'Daily Manga - Comic & Webtoon',
#  314: '漫咖 Comics - Manga,Novel and Stories',
#  315: 'Emmanuella Funny Videos 2018',
#  316: 'DC Comics',
#  317: 'Manga Zero - Japanese cartoon and comic reader',
#  318: 'Marvel Unlimited',
#  319: 'Tapas – Comics, Novels, and Stories',
#  320: "Children's cartoons (Mithu-Mina-Raju)",
#  321: "Narrator's Voice",
#  322: '【Ranobbe complete free】 Novelba - Free app that you can read and write novels',
#  323: 'Faustop Sounds',
#  324: 'Manga Mania - Best online manga reader',
#  325: '- Free Comics - Comic Apps',
#  326: 'Manga AZ - Manga Comic Reader',
#  327: 'Buff Thun - Daily Free Webtoon / Comics / Web Fiction / Mini Game',
#  328: "pixiv comic - everyone's manga app",
#  329: 'Funny Jokes and Stories 2018',
#  330: 'Hojiboy Tojiboyev Life Hacks',
#  331: 'Perfect Viewer',
#  332: 'Best Wallpapers Backgrounds(100,000+ 4K HD)',
#  333: 'think Comics',
#  334: 'Memes Button',
#  335: 'Laftel - Watching and Announcing Snooping, Streaming',
#  336: 'Messenger – Text and Video Chat for Free',
#  337: 'WhatsApp Messenger',
#  338: 'Messenger for SMS',
#  339: 'Google Chrome: Fast & Secure',
#  340: 'Messenger Lite: Free Calls & Messages',
#  341: 'Gmail',
#  342: 'Hangouts',
#  343: 'Viber Messenger',
#  344: 'My Tele2',
#  345: 'Firefox Browser fast & private',
#  346: 'Yahoo Mail – Stay Organized',
#  347: 'imo beta free calls and text',
#  348: 'imo free video calls and chat',
#  349: 'Contacts',
#  350: 'Call Free – Free Call',
#  351: 'Web Browser & Explorer',
#  352: 'Opera Mini - fast web browser',
#  353: 'Browser 4G',
#  354: 'MegaFon Dashboard',
#  355: 'ZenUI Dialer & Contacts',
#  356: 'Cricket Visual Voicemail',
#  357: 'Opera Browser: Fast and Secure',
#  358: 'TracFone My Account',
#  359: 'Firefox Focus: The privacy browser',
#  360: 'Google Voice',
#  361: 'Chrome Dev',
#  362: 'Xperia Link™',
#  363: 'TouchPal Keyboard - Fun Emoji & Android Keyboard',
#  364: 'Who',
#  365: 'Skype Lite - Free Video Call & Chat',
#  366: 'WeChat',
#  367: 'UC Browser Mini -Tiny Fast Private & Secure',
#  368: 'WhatsApp Business',
#  369: 'My magenta',
#  370: 'Android Messages',
#  371: 'Telegram',
#  372: 'Google Duo - High Quality Video Calls',
#  373: 'Puffin Web Browser',
#  374: 'Seznam.cz',
#  375: 'Antillean Gold Telegram (original version)',
#  376: 'AT&T Visual Voicemail',
#  377: 'GMX Mail',
#  378: 'Omlet Chat',
#  379: 'UC Browser - Fast Download Private & Secure',
#  380: 'My Vodacom SA',
#  381: 'Microsoft Edge',
#  385: 'Hangouts Dialer - Call Phones',
#  388: 'Talkatone: Free Texts, Calls & Phone Number',
#  389: 'Calls & Text by Mo+',
#  390: 'free video calls and chat',
#  392: 'Skype - free IM & video calls',
#  396: 'GO SMS Pro - Messenger, Free Themes, Emoji',
#  398: 'Messaging+ SMS, MMS Free',
#  399: 'chomp SMS',
#  400: 'Glide - Video Chat Messenger',
#  401: 'Text SMS',
#  402: 'Google Allo',
#  403: 'Talkray - Free Calls & Texts',
#  404: 'LINE: Free Calls & Messages',
#  405: 'GroupMe',
#  406: 'mysms SMS Text Messaging Sync',
#  407: 'BBM - Free Calls & Messages',
#  408: 'KakaoTalk: Free Calls & Text',
#  410: '2ndLine - Second Phone Number',
#  414: 'CM Browser - Ad Blocker , Fast Download , Privacy',
#  417: 'Ninesky Browser',
#  419: 'Dolphin Browser - Fast, Private & Adblock🐬',
#  422: 'Ghostery Privacy Browser',
#  423: 'InBrowser - Incognito Browsing',
#  424: 'Web Browser for Android',
#  425: 'DU Browser—Browse fast & fun',
#  426: 'Lightning Web Browser',
#  427: 'Web Browser',
#  428: 'Puffin Browser Pro',
#  429: 'Contacts+',
#  430: 'ExDialer - Dialer & Contacts',
#  433: 'PHONE for Google Voice & GTalk',
#  434: 'Safest Call Blocker',
#  435: 'Full Screen Caller ID',
#  436: 'Hiya - Caller ID & Block',
#  438: 'Mr. Number-Block calls & spam',
#  439: 'Should I Answer?',
#  440: 'RocketDial Dialer & Contacts',
#  441: 'CallApp: Caller ID, Blocker & Phone Call Recorder',
#  442: 'Whoscall - Caller ID & Block',
#  443: 'CIA - Caller ID & Call Blocker',
#  444: 'Calls Blacklist - Call Blocker',
#  445: 'Call Control - Call Blocker',
#  446: 'True Contact - Real Caller ID',
#  447: 'Video Caller Id',
#  448: 'Sync.ME – Caller ID & Block',
#  449: 'Burner - Free Phone Number',
#  450: 'Truecaller: Caller ID, SMS spam blocking & Dialer',
#  451: 'Caller ID +',
#  454: 'K-9 Mail',
#  455: 'myMail – Email for Hotmail, Gmail and Outlook Mail',
#  456: 'Email TypeApp - Mail App',
#  457: 'All Email Providers',
#  458: 'Newton Mail - Email App for Gmail, Outlook, IMAP',
#  459: 'GO Notifier',
#  460: 'Mail.Ru - Email App',
#  461: 'Mail1Click - Secure Mail',
#  462: 'Daum Mail - Next Mail',
#  463: 'mail.com mail',
#  464: 'SolMail - All-in-One email app',
#  471: 'Vonage Mobile® Call Video Text',
#  472: 'JusTalk - Free Video Calls and Fun Video Chat',
#  477: 'Moco+ - Chat, Meet People',
#  478: 'Calculator',
#  479: 'Truth or Dare Pro',
#  480: 'Private Dating, Hide App- Blue for PrivacyHider',
#  481: 'Ad Blocker for SayHi',
#  482: 'AMBW Dating App: Asian Men Black Women Interracial',
#  483: 'Zoosk Dating App: Meet Singles',
#  484: 'OkCupid Dating',
#  485: 'Match™ Dating - Meet Singles',
#  486: 'Hily: Dating, Chat, Match, Meet & Hook up',
#  487: 'Hinge: Dating & Relationships',
#  488: 'Casual Dating & Adult Singles - Joyride',
#  489: 'BBW Dating & Plus Size Chat',
#  490: 'Moco - Chat, Meet People',
#  491: 'CMB Free Dating App',
#  492: 'Hot or Not - Find someone right now',
#  493: 'eharmony - Online Dating App',
#  494: 'Free Dating App & Flirt Chat - Match with Singles',
#  495: 'Chispa, the Dating App for Latino, Latina Singles',
#  496: 'Clover Dating App',
#  497: 'Black People Meet Singles Date',
#  498: 'Mingle2 - Free Online Dating & Singles Chat Rooms',
#  499: 'Free Dating App & Flirt Chat - Cheers',
#  500: 'stranger chat - anonymous chat',
#  501: 'Blendr - Chat, Flirt & Meet',
#  502: 'Free Dating Hook Up Messenger',
#  503: 'Find Real Love — YouLove Premium Dating',
#  504: 'Once - Quality Matches Every day',
#  505: 'BLK - Swipe. Match. Chat.',
#  506: 'Cougar Dating Life : Date Older Women Sugar Mummy',
#  507: 'Howlr',
#  508: 'Stranger Chat & Date',
#  509: 'Free Dating & Flirt Chat - Choice of Love',
#  510: 'RandoChat - Chat roulette',
#  511: 'BeWild Free Dating & Chat App',
#  512: 'FastMeet: Chat, Dating, Love',
#  513: 'Free Dating App - YoCutie - Flirt, Chat & Meet',
#  514: 'OurTime Dating for Singles 50+',
#  515: 'FarmersOnly Dating',
#  516: 'Dating for 50 plus Mature Singles – FINALLY',
#  517: 'Sudy – Meet Elite & Rich Single',
#  518: 'Christian Dating For Free App',
#  519: 'Just She - Top Lesbian Dating',
#  520: 'Single Parent Meet #1 Dating',
#  521: 'EliteSingles – Dating for Single Professionals',
#  522: 'Millionaire Match: Rich Singles Dating App',
#  523: 'InterracialCupid - Interracial Dating App',
#  524: 'Sugar Mommas Dating And Single Search',
#  525: 'Hide App, Private Dating, Safe Chat - PrivacyHider',
#  526: 'muzmatch: Muslim & Arab Singles, Marriage & Dating',
#  527: 'NoBuffDating - Free Dating App',
#  528: 'Sugar Daddy Dating App',
#  529: 'Adult Dirty Emojis',
#  530: 'Free Dating App - Meet Local Singles - Flirt Chat',
#  531: 'Meet4U - Chat, Love, Singles!',
#  532: 'SnpCupid Dating',
#  533: 'Chat Rooms, Avatars, Date - Galaxy',
#  534: 'Adult Dating - AdultFinder',
#  535: 'Gay Sugar Daddy Dating & Hookup – Sudy Gay',
#  536: 'Meet24 - Love, Chat, Singles',
#  537: 'BBWCupid - BBW Dating App',
#  538: 'ChatVideo Meet new people',
#  539: 'TryDate - Free Online Dating App, Chat Meet Adults',
#  540: 'Black White Interracial Dating - Interracial Match',
#  541: 'USA Singles Meet, Match and Date Free - Date',
#  542: 'FlirtChat - ♥Free Dating/Flirting App♥',
#  547: 'The League',
#  553: 'Herpes Dating: 1,000K+ Singles',
#  556: 'Heart mill',
#  560: '95Live -SG#1 Live Streaming App',
#  564: 'Mutual - LDS Dating',
#  568: '2RedBeans',
#  570: 'SweetRing - Meet, Match, Date',
#  571: 'BiggerCity: Chat for gay bears, chubs & chasers',
#  573: 'SilverSingles: The 50+ Dating App',
#  574: 'Herpes Positive Singles Dating',
#  578: 'Glam - Premium Dating App',
#  579: 'iDates - Chats, Flirts, Dating, Love & Relations',
#  582: 'JustDating',
#  583: 'Interracial Match Dating App',
#  584: 'Russian Dating & Chat for Russian speaking RusDate',
#  585: 'Sky People (SPI): A secure blind date through authentication by Seoul National University',
#  586: 'Sweet mi - unlimited hunnam hunting blind date',
#  588: 'Mingle - Online Dating App to Chat & Meet People',
#  590: 'BBW Dating & Curvy Singles Chat- LargeFriends',
#  592: 'Hitwe - meet people and chat',
#  593: 'A hundred',
#  594: 'JustSayHi- Dating App. Chat & Meet Singles Nearby',
#  595: 'FERZU - Furries Social Network',
#  596: 'WannaMeet – Dating & Chat App',
#  598: 'Luxy Pro- Elite Dating Single',
#  599: 'Dating Network',
#  600: 'Chatting - Free chat, random chat, boyfriend, girlfriend',
#  601: 'iPair-Meet, Chat, Dating',
#  602: 'Meet, chat & date. Free dating app - Chocolate app',
#  603: 'Transenger – Ts Dating and Chat for Free',
#  604: 'O-Star',
#  605: 'Free Cam Girls - Live Webcam',
#  606: 'Cardi B Live Stream Video Chat - Prank',
#  607: 'Live Girls Talk - Free Video Chat',
#  608: 'Live Talk - Free Text and Video Chat',
#  609: 'Chat Kids - Chat Room For Kids',
#  610: 'Girls Live Chat - Free Text & Video Chat',
#  611: 'Random Video Chat',
#  612: 'MouseMingle',
#  613: 'American Girls Mobile Numbers',
#  614: 'Random Video Chat App With Strangers',
#  615: 'FREE VIDEO CHAT - LIVE VIDEO AND TEXT CHAT',
#  616: 'Awake Dating',
#  617: 'Live Chat - Free Video Chat Rooms',
#  618: 'Meet With Strangers: Video Chat & Dating',
#  619: 'FREE LIVE TALK',
#  620: 'Random Chat App with Strangers',
#  621: 'Ost. Zombies Cast - New Music and Lyrics',
#  622: 'Dating White Girls',
#  623: 'Live Chat - Free Video Talk',
#  624: 'Geeks Dating',
#  625: 'Live chat - free video chat',
#  626: 'House party - live chat',
#  627: 'Fishing Brain & Boating Maps Marine',
#  628: 'CAM5678 Video Chat',
#  629: 'Video chat live advices',
#  630: 'chat live chat',
#  631: 'Pet Lovers Dating',
#  632: 'Friend Find: free chat + flirt dating app',
#  633: 'Latin Dating',
#  634: 'Spine- The dating app',
#  635: 'Online Chat Girls Meet',
#  636: 'Wifi Mingle',
#  637: 'Girls Live Talk - Free Text and Video Chat',
#  638: 'Soy Luna - Top Music And Lyrics',
#  639: 'When Will You Get Married',
#  640: 'HOW TO ASK A GIRL OUT',
#  641: 'Online Girls Chat Group',
#  642: 'The DJ - Match with People',
#  643: 'Toronto Dating',
#  644: 'i miss you quotes and photos',
#  645: 'JoJo Siwa Top Hits Music',
#  646: 'UK Girls Mobile Numbers',
#  647: 'chat saudi arabia',
#  648: 'Chat Click - Dating Search',
#  649: 'Iraq love chat',
#  650: 'Healthy Relationships Guide',
#  651: 'following',
#  652: 'Gods by Night',
#  653: 'PlusOne',
#  654: 'Love Calendar - Couple Sharing Calendar & CoupleDay',
#  655: 'Speeding Joyride & Car Meet App',
#  656: 'LOBSTR - go on a lunch date',
#  657: 'Titanic App - Feminist Dating Application',
#  658: 'French Chat Room',
#  659: 'Soul Mate',
#  660: 'Diamond Engagement Rings',
#  661: 'Dating Tips For Men',
#  662: 'Halalguur',
#  670: 'Find Lover',
#  676: '2Date Dating App, Love and matching',
#  685: 'Teenage Chat & Dating',
#  687: 'Girls Online Talk - Free Text and Video Chat',
#  689: 'Online Girls Chat',
#  690: 'LIVE VIDEO TALK',
#  692: 'SkyLove – Dating and chat',
#  693: 'Free Live Talk-Video Call',
#  694: 'FindLoving',
#  695: 'Sugar Daddies Dating App',
#  699: 'Chat Mexico: meet people, flirt and friendship',
#  700: 'Duolingo: Learn Languages Free',
#  701: 'TED',
#  702: 'English Communication - Learn English for Chinese (Learn English for Chinese)',
#  703: 'Khan Academy',
#  704: 'Learn English with Wlingua',
#  705: 'Ai La Trieu Phu - ALTP Free',
#  706: 'Princess Coloring Book',
#  707: 'Learn Spanish - Español',
#  708: 'English Grammar Test',
#  709: 'Speed Reading',
#  710: 'English for beginners',
#  711: 'Flame - درب عقلك يوميا',
#  712: 'Mermaids',
#  713: 'Learn Japanese, Korean, Chinese Offline & Free',
#  714: 'Kids Mode',
#  715: 'PBS KIDS Video',
#  716: 'Dinosaurs Coloring Pages',
#  717: 'Cars Coloring Pages',
#  718: 'Babbel – Learn Languages',
#  719: 'Math Tricks',
#  720: 'Monster Truck Driver & Racing',
#  721: 'Learn English Words Free',
#  722: 'Japanese / English one-shop search dictionary - Free Japanese - English - Japanese dictionary application',
#  723: 'English speaking texts',
#  724: 'Thai Handwriting',
#  725: 'THAI DICT 2018',
#  726: 'Kanji test · Han search Kanji training (free version)',
#  727: "Game for KIDS: KIDS match'em",
#  728: 'Flippy Campus - Buy & sell on campus at a discount',
#  729: 'Free intellectual training game application |',
#  730: 'ABC Preschool Free',
#  731: 'PINKFONG Baby Shark',
#  732: 'English words application mikan',
#  733: 'Learn English for beginners',
#  734: 'Listen and learn English in seven days',
#  735: 'Lumosity: #1 Brain Games & Cognitive Training App',
#  736: 'Learn English from Persian: Persian to English',
#  737: 'English with Lingualeo',
#  738: 'Learn languages, grammar & vocabulary with Memrise',
#  741: 'Quizlet: Learn Languages & Vocab with Flashcards',
#  742: 'Udemy - Online Courses',
#  743: 'Coursera: Online courses',
#  744: 'edX - Online Courses by Harvard, MIT & more',
#  745: 'Elevate - Brain Training Games',
#  746: 'NeuroNation - Focus and Brain Training',
#  748: 'Peak – Brain Games & Training',
#  749: 'Memorado - Brain Games',
#  750: 'Lynda - Online Training Videos',
#  751: 'Brilliant',
#  752: 'CppDroid - C/C++ IDE',
#  753: 'Quiz&Learn Python',
#  754: 'C++ Tutorials',
#  755: 'C++ Programming',
#  756: 'C Programming',
#  757: 'Udacity - Lifelong Learning',
#  759: 'Learn C++',
#  760: 'Learn programming',
#  761: 'Learn JavaScript',
#  762: 'Learn Java',
#  763: 'Learn HTML',
#  764: 'Programming Hub, Learn to code',
#  765: 'Learn SQL',
#  766: 'Ready4 SAT (Prep4 SAT)',
#  767: 'Socratic - Math Answers & Homework Help',
#  768: 'Ready4 GMAT (Prep4 GMAT)',
#  769: 'Pocket GMAT Math',
#  770: 'GMAT Question Bank',
#  771: 'GRE Tutor',
#  772: 'GRE Flashcards',
#  773: 'play2prep: ACT, SAT prep',
#  774: 'SAT Test',
#  775: 'GMAT Math Flashcards',
#  776: 'Pocket SAT Math',
#  777: 'TOEFL Prep & Practice from Magoosh',
#  778: 'GRE Prep & Practice by Magoosh',
#  779: 'GRE® Flashcards by Kaplan',
#  780: 'SAT Vocabulary',
#  781: 'Magoosh GMAT Prep & Practice',
#  782: 'SAT Flashcards: Prep & Vocabulary',
#  791: 'Rosetta Stone: Learn to Speak & Read New Languages',
#  792: 'Google Classroom',
#  796: 'LinkedIn Learning: Online Courses to Learn Skills',
#  798: 'Learn English with Phrases',
#  799: 'Free english course',
#  801: 'Learn 50 languages',
#  803: 'Babbel – Learn Spanish',
#  804: 'Mango Languages: Lovable Language Courses',
#  805: 'Learn English with Aco',
#  806: 'Learn to Speak English',
#  809: 'busuu: Learn Languages - Spanish, English & More',
#  810: 'My Class Schedule: Timetable',
#  811: 'Study Checker',
#  812: 'My Study Life - School Planner',
#  813: 'HomeWork',
#  814: 'Next Gen Science Standards',
#  815: 'myHomework Student Planner',
#  816: "Teacher's Gradebook - Additio",
#  817: 'Common Core',
#  818: 'Homework Planner',
#  819: 'TeachersPayTeachers',
#  821: 'Edmodo',
#  822: 'Socrative Teacher',
#  823: 'Training schedule - AllUniver',
#  824: 'Remind: School Communication',
#  826: 'ClassDojo',
#  828: 'Lerni. Learn languages.',
#  830: 'HelloTalk — Chat, Speak & Learn Foreign Languages',
#  835: 'Innovative: Learn 34 Languages',
#  838: 'Chegg Study - Homework Help',
#  839: 'Canvas Student',
#  840: 'Timetable',
#  842: 'EasyBib: Citation Generator',
#  849: 'SoloLearn: Learn to Code for Free',
#  850: 'Kids Learn Languages by Mondly',
#  851: 'Blinkist - Nonfiction Books',
#  852: 'Sago Mini Hat Maker',
#  853: 'Fuzzy Numbers: Pre-K Number Foundation',
#  854: 'Toca Life: City',
#  855: 'Toca Life: Hospital',
#  856: 'Netflix',
#  857: 'Complete Spanish Movies',
#  858: 'Pluto TV - It’s Free TV',
#  859: 'Tubi TV - Free Movies & TV',
#  860: 'YouTube Kids',
#  861: 'Mobile TV',
#  862: 'TV+',
#  863: 'Digital TV',
#  864: 'Motorola Spotlight Player™',
#  865: 'Vigo Lite',
#  866: 'Google Play Games',
#  867: 'Hotstar',
#  868: 'Peers.TV: broadcast TV channels First, Match TV, TNT ...',
#  869: 'The green alien dance',
#  870: 'Spectrum TV',
#  871: 'H TV',
#  872: 'StarTimes - Live International Champions Cup',
#  873: 'Cinematic Cinematic',
#  874: 'MEGOGO - Cinema and TV',
#  875: 'Talking Angela',
#  876: 'DStv Now',
#  877: 'ivi - movies and TV shows in HD',
#  878: 'Radio Javan',
#  879: 'Viki: Asian TV Dramas & Movies',
#  880: 'Talking Ginger 2',
#  881: 'Girly Lock Screen Wallpaper with Quotes',
#  882: 'No.Draw - Colors by Number 2018',
#  883: '🔥 Football Wallpapers 4K | Full HD Backgrounds 😍',
#  884: 'Movies by Flixster, with Rotten Tomatoes',
#  885: 'Low Poly – Puzzle art game',
#  886: 'BBC Media Player',
#  887: 'Amazon Prime Video',
#  888: 'Adult Glitter Color by Number Book - Sandbox Pages',
#  889: 'IMDb Movies & TV',
#  890: 'Twitch: Livestream Multiplayer Games & Esports',
#  891: 'Ziggo GO',
#  892: 'YouTube Gaming',
#  893: 'PlayStation App',
#  894: 'Talking Ben the Dog',
#  895: 'Red Bull TV: Live Sports, Music & Entertainment',
#  896: 'Trailer Addict Movie Trailers',
#  897: 'Cinemark Theatres',
#  898: 'Regal Cinemas',
#  900: 'Fandango Movies - Times + Tickets',
#  901: 'Marcus Theatres',
#  902: 'Harkins Theatres',
#  903: 'AMC Theatres',
#  906: 'Food Network',
#  907: 'Cooking Channel',
#  908: 'Animal Planet GO',
#  909: 'VRV: Anime, game videos & more',
#  910: 'DramaFever: Stream Asian Drama Shows & Movies',
#  911: 'Crunchyroll - Everything Anime',
#  912: 'Investigation Discovery GO',
#  913: 'Crackle - Free TV & Movies',
#  914: 'CBS - Full Episodes & Live TV',
#  915: 'STARZ',
#  916: 'Acorn TV: World-class TV from Britain and Beyond',
#  917: 'HISTORY: Watch TV Show Full Episodes & Specials',
#  918: 'Nick',
#  919: 'VH1',
#  920: 'FOX NOW - On Demand & Live TV',
#  921: 'A&E - Watch Full Episodes of TV Shows',
#  922: 'The CW',
#  923: 'BET NOW - Watch Shows',
#  924: 'Hulu: Stream TV, Movies & more',
#  925: 'HBO NOW: Stream TV & Movies',
#  926: 'Univision NOW - Live TV and On Demand',
#  927: 'SHOWTIME',
#  928: 'Lifetime - Watch Full Episodes & Original Movies',
#  929: 'SeriesGuide – Show & Movie Manager',
#  930: 'Comedy Central',
#  942: 'CW Seed',
#  943: 'The NBC App - Watch Live TV and Full Episodes',
#  946: 'WWE',
#  949: 'Universal Kids',
#  950: 'MTV',
#  953: 'LEGO® TV',
#  954: 'HBO GO: Stream with TV Package',
#  955: 'Showtime Anytime',
#  956: 'PlayKids - Educational cartoons and games for kids',
#  957: 'FOX',
#  958: 'Telemundo Now',
#  961: 'Vudu Movies & TV',
#  970: 'Yidio: TV Show & Movie Guide',
#  974: 'Redbox',
#  977: 'Tribeca Shortlist - Handpicked Movies',
#  987: 'Nick Jr. - Shows & Games',
#  988: 'Sticker Market: Emoji keyboard',
#  990: 'Kidjo TV Kids Have Fun & Learn',
#  991: 'Laugh Out Loud by Kevin Hart',
#  992: 'ColorFul - Adult Coloring Book',
#  995: 'Hamilton — The Official App',
#  996: 'My Talking Pet',
#  997: 'Funny Pics',
#  998: 'Funny Quotes Free',
#  999: 'LOL Pics (Funny Pictures)',
#  1000: 'Meme Creator',
#  1001: 'Imgur: Find funny GIFs, memes & watch viral videos',
#  1002: 'Meme Generator',
#  1003: 'SketchBook - draw and paint',
#  1004: 'Colorfy: Coloring Book for Adults - Free',
#  1005: 'All Events in City',
#  1006: 'Ticketmaster Event Tickets',
#  1007: 'Reminder',
#  1008: 'Birdays - Birthday reminder',
#  1009: 'StubHub - Tickets to Sports, Concerts & Events',
#  1010: 'Fever',
#  1011: 'DroidAdmin for Android - Advice',
#  1012: 'SeatGeek – Tickets to Sports, Concerts, Broadway',
#  1013: 'my4D',
#  1014: 'VAN NIAN 2018 - Vietnamese Calendar',
#  1015: 'Vivid Seats – Event Tickets',
#  1016: 'Name days',
#  1017: 'LBB - Find New & Unique Things To Do Around You',
#  1018: 'Happy Birthday Songs Offline',
#  1019: 'Series Valley of the Wolves full of part',
#  1020: 'Mummatikabalkuragi',
#  1021: 'Gametime - Tickets to Sports, Concerts, Theater',
#  1022: 'PTI Flex Maker, Photo Frame Editor & Songs 2018',
#  1023: 'Wipe out',
#  1024: 'Birthdays & Other Events',
#  1025: 'Sarajevo Film Festival - Official',
#  1026: 'Summer Madness',
#  1027: 'Events High - Meet Your City!',
#  1028: 'vide-greniers.org',
#  1029: 'SUMMER SONIC app',
#  1030: 'Quake & Volcanoes: 3D Globe of Volcanic Eruptions',
#  1031: 'Prosperity',
#  1032: "Picktrainer: India's largest photo contest app",
#  1033: 'AAS-IN-ASIA 2018',
#  1034: 'Moot Peru 2018',
#  1035: 'FM News',
#  1036: 'Goldstar: Live Event Tickets',
#  1037: 'Emmabodafestivalen',
#  1038: 'KudaGo - things to do in NY',
#  1039: 'Mindvalley U Tallinn 2018',
#  1040: 'Rockmaraton Info',
#  1041: 'Freitas Auctioneer Official',
#  1042: 'mobLee Events',
#  1043: 'Xceed - Clubs, DJs, Festivals & Tickets',
#  1044: 'AMM Events & CPD',
#  1045: 'Arab Halls - For Wedding & Events',
#  1046: 'MeAuDote - An act of love that saves a life',
#  1047: 'TCF National Conference',
#  1048: 'Endurance Lifestyle',
#  1049: 'K PLUS',
#  1050: 'ING Banking',
#  1051: 'Citibanamex Movil',
#  1052: 'The postal bank',
#  1053: 'KTB Netbank',
#  1054: 'Mobile Bancomer',
#  1055: 'Nedbank Money',
#  1056: 'SCB EASY',
#  1057: 'CASHIER',
#  1058: 'Rabo Banking',
#  1059: 'Capitec Remote Banking',
#  1060: 'Itau bank',
#  1061: 'Nubank',
#  1062: 'The Societe Generale App',
#  1063: 'IKO',
#  1064: 'Cash App',
#  1065: 'Standard Bank / Stanbic Bank',
#  1066: 'Bualuang mBanking',
#  1067: 'Intesa Sanpaolo Mobile',
#  1068: 'UBA Mobile Banking',
#  1069: 'BBVA Spain',
#  1070: 'MyMo by GSB',
#  1071: 'VTB-Online',
#  1072: 'Ecobank Mobile Banking',
#  1073: 'Banorte Movil',
#  1074: 'Wells Fargo Mobile',
#  1075: 'Credit Karma',
#  1076: 'BZWBK24 mobile',
#  1077: 'PayPal',
#  1078: 'Capital One® Mobile',
#  1079: 'Zenith Bank Mobile App',
#  1080: 'GCash - Buy Load, Pay Bills, Send Money',
#  1081: 'Post Bank',
#  1082: 'İşCep',
#  1083: "People's Bank",
#  1084: 'Google Pay',
#  1085: 'Transfer',
#  1086: 'T-Mobile in',
#  1087: 'TrueMoney Wallet',
#  1088: 'Alfa-Bank (Alfa-Bank)',
#  1089: 'Bank of Brazil',
#  1090: 'WiseBanyan - Invest For Free',
#  1091: 'Robinhood - Investing, No Fees',
#  1092: 'Wells Fargo Daily Change',
#  1093: 'Even - organize your money, get paid early',
#  1094: 'Digit Save Money Automatically',
#  1095: 'Stash: Invest. Learn. Save.',
#  1096: 'Acorns - Invest Spare Change',
#  1098: 'Money Lover: Expense Tracker, Budget Planner',
#  1099: 'Expense IQ Money Manager',
#  1100: 'Money Manager Expense & Budget',
#  1102: 'Prism Pay Bills, Track Money, Personal Finance',
#  1103: 'Monefy - Money Manager',
#  1104: 'Simple - Better Banking',
#  1105: 'Chime - Mobile Banking',
#  1106: 'Bluebird by American Express',
#  1107: 'Walmart MoneyCard',
#  1108: 'Moven - Smart Finances',
#  1109: 'Qapital - Save Small. Live Large',
#  1110: 'Experian - Free Credit Report',
#  1111: 'Branch',
#  1112: 'WalletHub - Free Credit Score, Report & Monitoring',
#  1113: 'CreditWise from Capital One',
#  1114: 'NerdWallet: Personal Finance, Credit Score & Cash',
#  1116: 'my face',
#  1117: 'Credit Sesame',
#  1118: 'Mint: Budget, Bills, Finance',
#  1119: 'Fresh EBT - Food Stamp Balance',
#  1120: 'Hurdlr: Track Mileage, Expenses, and Log Receipts',
#  1121: 'Mobills: Budget Planner',
#  1122: 'Everlance: Free Mileage Log',
#  1123: 'MileIQ - Free Mileage Tracker for Business',
#  1124: 'QuickBooks Self-Employed:Mileage Tracker and Taxes',
#  1125: 'FREE Stock Market Trading Tips',
#  1126: 'MetaTrader 5',
#  1127: 'MetaTrader 4',
#  1128: 'Stock Quote',
#  1129: 'Seeking Alpha',
#  1130: 'Stock Trainer: Virtual Trading (Stock Markets)',
#  1131: 'Stocks: Realtime Quotes Charts',
#  1132: 'Stocks, Forex, Bitcoin, Ethereum: Portfolio & News',
#  1133: 'CNBC: Breaking Business News & Live Market Data',
#  1134: 'US Stock Market',
#  1135: 'Bloomberg Professional',
#  1136: 'E*TRADE Mobile',
#  1138: 'MSN Money- Stock Quotes & News',
#  1139: 'Fox Business',
#  1140: 'NSE Mobile Trading',
#  1141: 'Yahoo Finance',
#  1142: 'JStock - Stock Market, Portfolio & News',
#  1145: 'Webull - Stock Quotes & Free Stock Trading',
#  1146: 'Trading 212 - Forex, Stocks, CFDs',
#  1147: 'Moneycontrol – Stocks, Sensex, Mutual Funds, IPO',
#  1148: 'Current debit card and app made for teens',
#  1151: 'Betterment',
#  1152: 'Citizens Bank Mobile Banking',
#  1153: 'GoBank',
#  1154: 'NetSpend Prepaid',
#  1155: 'BBVA Compass Banking',
#  1158: 'BankMobile Vibe App',
#  1159: 'Netspend Skylight ONE',
#  1160: 'ACE Elite',
#  1161: 'U.S. Bank',
#  1162: 'Huntington Mobile',
#  1163: 'USAA Mobile',
#  1165: 'Associated Credit Union Mobile',
#  1166: 'Bank of America Mobile Banking',
#  1167: 'USE Credit Union Mobile',
#  1168: 'Discover Mobile',
#  1171: 'Amex Mobile',
#  1172: 'Citi Mobile®',
#  1173: 'Navy Federal Credit Union',
#  1174: 'Chase Mobile',
#  1175: 'HDFC Bank MobileBanking',
#  1176: 'Barclays US for Android',
#  1177: "McDonald's",
#  1178: 'Easy and Fast Recipes',
#  1179: 'Cookpad - FREE recipe search makes fun cooking · musical making!',
#  1180: 'DELISH KITCHEN - FREE recipe movies make food fun and easy!',
#  1181: 'Sumine side dish - dish recipe side dish',
#  1182: 'Easy Recipes',
#  1183: 'Delicious Recipes',
#  1184: 'Tastely',
#  1185: 'Pastry & Cooking (Without Net)',
#  1186: 'Frigo Magic: Easy recipe idea and anti-waste',
#  1187: "McDonald's - McDonald's Japan",
#  1188: 'Debonairs Pizza',
#  1189: 'Popeyes® App',
#  1190: "Dunkin' Donuts",
#  1191: 'Pyaterochka',
#  1192: 'Refreshing app Free application that can use deal coupons',
#  1193: 'Simple Recipes',
#  1194: 'Grubhub: Food Delivery',
#  1195: 'Panera Bread',
#  1196: 'Chick-fil-A',
#  1197: 'hellofood - Food Delivery',
#  1198: 'Starbucks',
#  1199: 'Easy and quick desserts',
#  1200: "Domino's Pizza USA",
#  1201: 'Chef - Recipes & Cooking',
#  1202: 'Delivery Club-food delivery: pizza, sushi, burger, salad',
#  1203: 'HungerStation',
#  1204: 'Delivery yogi.',
#  1205: 'Delivery trough - delivery trough delivery trough',
#  1206: 'Dr. Oetker recipe ideas',
#  1207: 'SONIC Drive-In',
#  1208: 'SUBWAY®',
#  1209: 'GialloZafferano: Recipes',
#  1210: 'Dairy Queen',
#  1211: '9th stage',
#  1212: 'OpenRice',
#  1213: 'SarashpazPapion (Cooking with Chef Bowls)',
#  1214: 'Little Caesars',
#  1215: 'Recipes Pastries and homemade pies More than 500 recipes for pastries',
#  1216: 'Om Waleed Sweets',
#  1217: 'Eat Fast Prepare "Without Internet"',
#  1218: 'Wendy’s – Food and Offers',
#  1219: 'My Recipes Cookbook : RecetteTek',
#  1220: 'Healthy Recipes Free',
#  1221: 'Cookbook Recipes',
#  1222: 'ChefTap Recipes & Grocery List',
#  1223: 'Recipe Keeper',
#  1224: 'My CookBook (Recipe Manager)',
#  ...}

# %%
d_app_dupe
# Out:
# {230: 'Quick PDF Scanner + OCR FREE',
#  237: 'Box',
#  240: 'Google My Business',
#  257: 'ZOOM Cloud Meetings',
#  262: 'join.me - Simple Meetings',
#  266: 'Box',
#  267: 'Zenefits',
#  268: 'Google Ads',
#  269: 'Google My Business',
#  270: 'Slack',
#  271: 'FreshBooks Classic',
#  272: 'Insightly CRM',
#  273: 'QuickBooks Accounting: Invoicing & Expenses',
#  274: 'HipChat - Chat Built for Teams',
#  275: 'Xero Accounting Software',
#  276: 'MailChimp - Email, Marketing Automation',
#  277: 'Crew - Free Messaging and Scheduling',
#  278: 'Asana: organize team projects',
#  279: 'Google Analytics',
#  280: 'AdWords Express',
#  281: 'Accounting App - Zoho Books',
#  282: 'Invoice & Time Tracking - Zoho',
#  283: 'join.me - Simple Meetings',
#  284: 'Invoice 2go — Professional Invoices and Estimates',
#  285: 'SignEasy | Sign and Fill PDF and other Documents',
#  286: 'Quick PDF Scanner + OCR FREE',
#  287: 'Genius Scan - PDF Scanner',
#  288: 'Tiny Scanner - PDF Scanner App',
#  289: 'Fast Scanner : Free PDF Scan',
#  290: 'Mobile Doc Scanner (MDScan) Lite',
#  291: 'TurboScan: scan documents and receipts in PDF',
#  292: 'Tiny Scanner Pro: PDF Doc Scan',
#  293: 'Docs To Go™ Free Office Suite',
#  294: 'OfficeSuite : Free Office + PDF Editor',
#  295: 'Slack',
#  297: 'QuickBooks Accounting: Invoicing & Expenses',
#  382: 'WhatsApp Messenger',
#  383: 'Messenger – Text and Video Chat for Free',
#  384: 'imo free video calls and chat',
#  386: 'Viber Messenger',
#  387: 'Hangouts',
#  391: 'WeChat',
#  393: 'Telegram',
#  394: 'Who',
#  395: 'Google Voice',
#  397: 'Android Messages',
#  409: 'Firefox Focus: The privacy browser',
#  411: 'Google Allo',
#  412: 'Google Chrome: Fast & Secure',
#  413: 'Firefox Browser fast & private',
#  415: 'Puffin Web Browser',
#  416: 'Opera Browser: Fast and Secure',
#  418: 'Opera Mini - fast web browser',
#  420: 'UC Browser Mini -Tiny Fast Private & Secure',
#  421: 'UC Browser - Fast Download Private & Secure',
#  431: 'Calls & Text by Mo+',
#  432: 'Viber Messenger',
#  437: 'Call Blocker',
#  452: 'Gmail',
#  453: 'Yahoo Mail – Stay Organized',
#  465: 'Hangouts',
#  466: 'imo free video calls and chat',
#  467: 'free video calls and chat',
#  468: 'Viber Messenger',
#  469: 'Skype - free IM & video calls',
#  470: 'WeChat',
#  473: 'Glide - Video Chat Messenger',
#  474: 'Talkray - Free Calls & Texts',
#  475: 'LINE: Free Calls & Messages',
#  476: 'KakaoTalk: Free Calls & Text',
#  543: 'OkCupid Dating',
#  544: 'CMB Free Dating App',
#  545: 'Hily: Dating, Chat, Match, Meet & Hook up',
#  546: 'Hinge: Dating & Relationships',
#  548: 'BBW Dating & Plus Size Chat',
#  549: 'Casual Dating & Adult Singles - Joyride',
#  550: 'EliteSingles – Dating for Single Professionals',
#  551: 'Clover Dating App',
#  552: 'Moco - Chat, Meet People',
#  554: 'Hot or Not - Find someone right now',
#  555: 'Just She - Top Lesbian Dating',
#  557: 'Once - Quality Matches Every day',
#  558: 'Sudy – Meet Elite & Rich Single',
#  559: 'muzmatch: Muslim & Arab Singles, Marriage & Dating',
#  561: 'Chispa, the Dating App for Latino, Latina Singles',
#  562: 'Blendr - Chat, Flirt & Meet',
#  563: 'Find Real Love — YouLove Premium Dating',
#  565: 'Cougar Dating Life : Date Older Women Sugar Mummy',
#  566: 'stranger chat - anonymous chat',
#  567: 'Millionaire Match: Rich Singles Dating App',
#  569: 'Dating for 50 plus Mature Singles – FINALLY',
#  572: 'Moco+ - Chat, Meet People',
#  575: 'Chat Rooms, Avatars, Date - Galaxy',
#  576: 'FastMeet: Chat, Dating, Love',
#  577: 'Christian Dating For Free App',
#  580: 'Meet24 - Love, Chat, Singles',
#  581: 'Black White Interracial Dating - Interracial Match',
#  587: 'Gay Sugar Daddy Dating & Hookup – Sudy Gay',
#  589: 'Adult Dirty Emojis',
#  591: 'Hide App, Private Dating, Safe Chat - PrivacyHider',
#  597: 'Meet4U - Chat, Love, Singles!',
#  663: '95Live -SG#1 Live Streaming App',
#  664: 'Just She - Top Lesbian Dating',
#  665: 'Hily: Dating, Chat, Match, Meet & Hook up',
#  666: 'O-Star',
#  667: 'Random Video Chat',
#  668: 'Black People Meet Singles Date',
#  669: 'Howlr',
#  671: 'Free Dating & Flirt Chat - Choice of Love',
#  672: 'Cardi B Live Stream Video Chat - Prank',
#  673: 'Chat Kids - Chat Room For Kids',
#  674: 'muzmatch: Muslim & Arab Singles, Marriage & Dating',
#  675: 'BBW Dating & Plus Size Chat',
#  677: 'Transenger – Ts Dating and Chat for Free',
#  678: 'BBW Dating & Curvy Singles Chat- LargeFriends',
#  679: 'MouseMingle',
#  680: 'FlirtChat - ♥Free Dating/Flirting App♥',
#  681: 'Live Talk - Free Text and Video Chat',
#  682: 'Adult Dirty Emojis',
#  683: 'Free Cam Girls - Live Webcam',
#  684: 'Random Video Chat App With Strangers',
#  686: 'Live Girls Talk - Free Video Chat',
#  688: 'Girls Live Chat - Free Text & Video Chat',
#  691: 'Free Dating App - Meet Local Singles - Flirt Chat',
#  696: 'iPair-Meet, Chat, Dating',
#  697: 'Free Dating Hook Up Messenger',
#  698: 'Free Dating App - YoCutie - Flirt, Chat & Meet',
#  739: 'Khan Academy',
#  740: 'TED',
#  747: 'Lumosity: #1 Brain Games & Cognitive Training App',
#  758: 'Udemy - Online Courses',
#  783: 'Khan Academy',
#  784: 'TED',
#  785: 'Duolingo: Learn Languages Free',
#  786: 'Quizlet: Learn Languages & Vocab with Flashcards',
#  787: 'Coursera: Online courses',
#  788: 'Udemy - Online Courses',
#  789: 'Udacity - Lifelong Learning',
#  790: 'edX - Online Courses by Harvard, MIT & more',
#  793: 'Lynda - Online Training Videos',
#  794: 'Learn languages, grammar & vocabulary with Memrise',
#  795: 'Brilliant',
#  797: 'Babbel – Learn Languages',
#  800: 'Duolingo: Learn Languages Free',
#  802: 'Rosetta Stone: Learn to Speak & Read New Languages',
#  807: 'Learn languages, grammar & vocabulary with Memrise',
#  808: 'Learn English with Wlingua',
#  820: 'Quizlet: Learn Languages & Vocab with Flashcards',
#  825: 'Google Classroom',
#  827: 'Duolingo: Learn Languages Free',
#  829: 'Learn 50 languages',
#  831: 'Mango Languages: Lovable Language Courses',
#  832: 'Rosetta Stone: Learn to Speak & Read New Languages',
#  833: 'Learn languages, grammar & vocabulary with Memrise',
#  834: 'Babbel – Learn Languages',
#  836: 'busuu: Learn Languages - Spanish, English & More',
#  837: 'My Class Schedule: Timetable',
#  841: 'Socratic - Math Answers & Homework Help',
#  843: 'Google Classroom',
#  844: 'ClassDojo',
#  845: 'HelloTalk — Chat, Speak & Learn Foreign Languages',
#  846: 'Quizlet: Learn Languages & Vocab with Flashcards',
#  847: 'busuu: Learn Languages - Spanish, English & More',
#  848: 'Rosetta Stone: Learn to Speak & Read New Languages',
#  899: 'Movies by Flixster, with Rotten Tomatoes',
#  904: 'IMDb Movies & TV',
#  905: 'Netflix',
#  931: 'IMDb Movies & TV',
#  932: 'Netflix',
#  933: 'Tubi TV - Free Movies & TV',
#  934: 'Crunchyroll - Everything Anime',
#  935: 'STARZ',
#  936: 'Crackle - Free TV & Movies',
#  937: 'CBS - Full Episodes & Live TV',
#  938: 'Nick',
#  939: 'Hulu: Stream TV, Movies & more',
#  940: 'FOX NOW - On Demand & Live TV',
#  941: 'The CW',
#  944: 'HISTORY: Watch TV Show Full Episodes & Specials',
#  945: 'HBO NOW: Stream TV & Movies',
#  947: 'A&E - Watch Full Episodes of TV Shows',
#  948: 'VH1',
#  951: 'Lifetime - Watch Full Episodes & Original Movies',
#  952: 'BET NOW - Watch Shows',
#  959: 'Netflix',
#  960: 'Tubi TV - Free Movies & TV',
#  962: 'Crackle - Free TV & Movies',
#  963: 'Crunchyroll - Everything Anime',
#  964: 'Nick',
#  965: 'STARZ',
#  966: 'Hulu: Stream TV, Movies & more',
#  967: 'Food Network',
#  968: 'FOX NOW - On Demand & Live TV',
#  969: 'Movies by Flixster, with Rotten Tomatoes',
#  971: 'HISTORY: Watch TV Show Full Episodes & Specials',
#  972: 'Viki: Asian TV Dramas & Movies',
#  973: 'The CW',
#  975: 'Univision NOW - Live TV and On Demand',
#  976: 'HBO NOW: Stream TV & Movies',
#  978: 'A&E - Watch Full Episodes of TV Shows',
#  979: 'VH1',
#  980: 'SHOWTIME',
#  981: 'MTV',
#  982: 'Lifetime - Watch Full Episodes & Original Movies',
#  983: 'Comedy Central',
#  984: 'BET NOW - Watch Shows',
#  985: 'FOX',
#  986: 'Telemundo Now',
#  989: 'Viki: Asian TV Dramas & Movies',
#  993: 'Nick',
#  994: 'Fandango Movies - Times + Tickets',
#  1097: 'Google Pay',
#  1101: 'Wells Fargo Daily Change',
#  1115: 'Credit Karma',
#  1137: 'Robinhood - Investing, No Fees',
#  1143: 'Digit Save Money Automatically',
#  1144: 'Acorns - Invest Spare Change',
#  1149: 'Money Lover: Expense Tracker, Budget Planner',
#  1150: 'Mint: Budget, Bills, Finance',
#  1156: 'Simple - Better Banking',
#  1157: 'PayPal',
#  1164: 'Google Pay',
#  1169: 'Wells Fargo Mobile',
#  1170: 'Capital One® Mobile',
#  1240: 'Grubhub: Food Delivery',
#  1242: 'Postmates Food Delivery: Order Eats & Alcohol',
#  1243: "Domino's Pizza USA",
#  1250: 'Chick-fil-A',
#  1256: 'Zomato - Restaurant Finder and Food Delivery App',
#  1309: 'Run with Map My Run',
#  1319: 'Weight Loss Running by Verv',
#  1320: 'Nike+ Run Club',
#  1324: 'Runtastic Running App & Mile Tracker',
#  1325: '8fit Workouts & Meal Planner',
#  1347: 'Daily Yoga - Yoga Fitness Plans',
#  1348: 'Pocket Yoga',
#  1363: 'Calorie Counter - MyFitnessPal',
#  1373: 'Weight Loss Running by Verv',
#  1374: 'Nike+ Run Club',
#  1375: 'Seven - 7 Minute Workout Training Challenge',
#  1380: 'Weight Watchers Mobile',
#  1381: 'Walk with Map My Walk',
#  1382: 'Workout Trainer: fitness coach',
#  1384: 'Run with Map My Run',
#  1385: 'Nike Training Club - Workouts & Fitness Plans',
#  1386: 'Fitbit Coach',
#  1387: 'Calorie Counter - MyFitnessPal',
#  1388: 'Endomondo - Running & Walking',
#  1389: 'Runkeeper - GPS Track Run Walk',
#  1390: 'Nike+ Run Club',
#  1392: 'Runtastic Running App & Mile Tracker',
#  1405: 'Calorie Counter - MyFitnessPal',
#  1406: 'Lose It! - Calorie Counter',
#  1407: 'Calorie Counter - MyNetDiary',
#  1408: '10 Best Foods for You',
#  1410: 'MyPlate Calorie Tracker',
#  1411: 'Weight Loss Tracker - RecStyle',
#  1412: 'Calorie Counter by FatSecret',
#  1414: 'Calorie Counter - Macros',
#  1415: 'My Diet Diary Calorie Counter',
#  1416: 'Lark - 24/7 Health Coach',
#  1417: 'Weight Watchers Mobile',
#  1418: 'Calorie Counter & Diet Tracker',
#  1419: 'MealLogger-Photo Food Journal',
#  1420: 'Health and Nutrition Guide',
#  1421: 'Food Calorie Calculator',
#  1422: 'Calorie Counter - MyFitnessPal',
#  1423: 'Lose It! - Calorie Counter',
#  1425: 'Relax Meditation: Sleep with Sleep Sounds',
#  1431: 'Meditation Music - Relax, Yoga',
#  1435: '21-Day Meditation Experience',
#  1437: 'Fabulous: Motivate Me! Meditate, Relax, Sleep',
#  1439: 'Calm - Meditate, Sleep, Relax',
#  1442: 'Relax Melodies: Sleep Sounds',
#  1444: 'Simple Habit Meditation',
#  1445: 'Headspace: Meditation & Mindfulness',
#  1446: 'Daily Yoga - Yoga Fitness Plans',
#  1497: 'Houzz Interior Design Ideas',
#  1503: 'Mortgage by Zillow: Calculator & Rates',
#  1504: 'Redfin Real Estate',
#  1505: 'Apartment List: Housing, Apt, and Property Rentals',
#  1506: 'Realtor.com Real Estate: Homes for Sale and Rent',
#  1507: 'Trulia Real Estate & Rentals',
#  1508: 'Zillow: Find Houses for Sale & Apartments for Rent',
#  1510: 'Apartments & Rentals - Zillow',
#  1511: 'Trulia Rent Apartments & Homes',
#  1512: 'Apartments.com Rental Search',
#  1513: 'Houzz Interior Design Ideas',
#  1612: 'Vaniday - Beauty Booking App',
#  1617: 'StyleSeat',
#  1622: 'JOANN - Crafts & Coupons',
#  1627: 'Fashion in Vogue',
#  1629: 'Wheretoget: Shop in style',
#  1630: 'My Dressing - Fashion closet',
#  1631: 'Chictopia',
#  1632: 'Scarf Fashion Designer',
#  1633: 'Fashion in Vogue',
#  1634: 'Zara',
#  1701: 'Subway Surfers',
#  1702: 'ROBLOX',
#  1703: 'Pou',
#  1704: '8 Ball Pool',
#  1705: 'Clash of Clans',
#  1706: 'Candy Crush Saga',
#  1707: 'Plants vs. Zombies FREE',
#  1711: 'My Talking Angela',
#  1712: 'Bubble Shooter',
#  1716: 'Word Search',
#  1717: 'Candy Crush Soda Saga',
#  1718: 'Fishdom',
#  1720: 'Block Puzzle',
#  1722: 'Clash Royale',
#  1724: 'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  1725: 'Granny',
#  1726: 'Galaxy Attack: Alien Shooter',
#  1727: 'Angry Birds Rio',
#  1728: 'Zombie Catchers',
#  1729: 'Zombie Hunter King',
#  1730: 'Temple Run 2',
#  1731: 'Zombie Tsunami',
#  1734: 'Farm Heroes Saga',
#  1735: 'Super Jim Jump - pixel 3d',
#  1736: 'slither.io',
#  1741: 'Angry Birds Classic',
#  1745: 'Flow Free',
#  1749: 'ROBLOX',
#  1750: 'Helix Jump',
#  1751: 'Subway Surfers',
#  1752: 'Candy Crush Saga',
#  1753: 'Toon Blast',
#  1755: 'Granny',
#  1756: '8 Ball Pool',
#  1757: 'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  1758: 'slither.io',
#  1760: 'Temple Run 2',
#  1761: 'Kick the Buddy',
#  1762: 'Magic Tiles 3',
#  1763: 'Bowmasters',
#  1766: 'Wordscapes',
#  1779: 'Block Craft 3D: Building Simulator Games For Free',
#  1793: 'Helix Jump',
#  1795: 'PUBG MOBILE',
#  1798: 'Wordscapes',
#  1841: 'DRAGON BALL LEGENDS',
#  1842: 'ROBLOX',
#  1843: 'Candy Crush Saga',
#  1845: '8 Ball Pool',
#  1847: 'Harry Potter: Hogwarts Mystery',
#  1848: 'PUBG MOBILE',
#  1850: 'MARVEL Strike Force',
#  1856: 'Merge Dragons!',
#  1866: 'Honkai Impact 3rd',
#  1870: 'Candy Crush Saga',
#  1871: 'ROBLOX',
#  1872: '8 Ball Pool',
#  1873: 'Subway Surfers',
#  1874: 'Candy Crush Soda Saga',
#  1875: 'Zombie Hunter King',
#  1876: 'Bubble Shooter',
#  1877: 'Toon Blast',
#  1878: 'Toy Blast',
#  1879: 'Clash Royale',
#  1880: 'Clash of Clans',
#  1881: 'Farm Heroes Saga',
#  1882: 'Plants vs. Zombies FREE',
#  1883: 'Word Search',
#  1884: 'Block Puzzle',
#  1885: 'Super Jim Jump - pixel 3d',
#  1886: 'Pou',
#  1887: 'Temple Run 2',
#  1888: 'Flow Free',
#  1889: 'Homescapes',
#  1890: 'Wordscapes',
#  1891: 'My Talking Angela',
#  1892: 'slither.io',
#  1893: 'Cooking Fever',
#  1895: 'Gardenscapes',
#  1896: 'Fishdom',
#  1897: 'Galaxy Attack: Alien Shooter',
#  1898: 'Score! Hero',
#  1899: 'Zombie Catchers',
#  1900: 'Magic Tiles 3',
#  1902: 'Granny',
#  1903: 'Dream League Soccer 2018',
#  1905: 'Fruits Bomb',
#  1906: 'Angry Birds Classic',
#  1907: 'Talking Tom Gold Run',
#  1908: 'Bowmasters',
#  1909: 'My Talking Tom',
#  1910: 'Hill Climb Racing',
#  1911: 'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  1912: 'Pixel Art: Color by Number Game',
#  1914: 'Rider',
#  1915: 'Zombie Tsunami',
#  1916: 'Garena Free Fire',
#  1918: 'Subway Surfers',
#  1919: 'Helix Jump',
#  1921: 'Temple Run 2',
#  1922: 'slither.io',
#  1923: 'Bowmasters',
#  1924: 'Talking Tom Gold Run',
#  1925: 'Zombie Catchers',
#  1926: 'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  1929: 'Miraculous Ladybug & Cat Noir - The Official Game',
#  1930: 'Kick the Buddy',
#  1936: 'DRAGON BALL LEGENDS',
#  1949: 'Zombie Hunter King',
#  1950: 'Garena Free Fire',
#  1967: 'Candy Crush Saga',
#  1968: 'Plants vs. Zombies FREE',
#  1969: 'Block Puzzle',
#  1970: 'Helix Jump',
#  1971: '8 Ball Pool',
#  1973: 'Bubble Shooter',
#  1974: 'Solitaire',
#  1977: 'Traffic Racer',
#  1978: 'Hill Climb Racing',
#  1979: 'Earn to Die 2',
#  1980: 'Bubble Shooter 2',
#  1982: 'Flow Free',
#  1983: 'Zombie Catchers',
#  1985: 'Angry Birds Rio',
#  1986: 'Candy Crush Jelly Saga',
#  1987: 'Cut the Rope FULL FREE',
#  1988: 'Jewels Star: OZ adventure',
#  1989: 'Hungry Shark Evolution',
#  1991: 'Angry Birds Classic',
#  1992: 'Best Fiends - Free Puzzle Game',
#  1993: 'Hill Climb Racing 2',
#  1997: 'Swamp Attack',
#  2000: 'Bowmasters',
#  2001: 'Magic Tiles 3',
#  2002: 'Block Puzzle Classic Legend !',
#  2004: 'Pixel Art: Color by Number Game',
#  2005: 'Score! Hero',
#  2009: 'Zombie Tsunami',
#  2010: 'DEAD TARGET: FPS Zombie Apocalypse Survival Games',
#  2011: 'Word Search',
#  2012: 'Farm Heroes Saga',
#  2015: 'YouTube Kids',
#  2016: 'Candy Bomb',
#  2017: 'ROBLOX',
#  2025: 'Solitaire',
#  2026: 'Princess Coloring Book',
#  2027: 'Hello Kitty Nail Salon',
#  2030: 'Dog Run - Pet Dog Simulator',
#  2034: 'Coloring book moana',
#  2042: 'Bubble Shooter',
#  2046: 'Barbie™ Fashion Closet',
#  2051: 'Minion Rush: Despicable Me Official Game',
#  2055: 'No.Draw - Colors by Number 2018',
#  2057: 'Duolingo: Learn Languages Free',
#  2066: 'Super ABC! Learning games for kids! Preschool apps',
#  2089: 'ROBLOX',
#  2090: 'PJ Masks: Moonlight Heroes',
#  2091: 'Minion Rush: Despicable Me Official Game',
#  2092: 'Dog Run - Pet Dog Simulator',
#  2094: 'Hot Wheels: Race Off',
#  2096: 'Farming Simulator 14',
#  2112: 'Mcqueen Coloring pages',
#  2114: 'Monster Truck Driver & Racing',
#  2116: 'Strawberry Shortcake BerryRush',
#  2125: 'DC Super Hero Girls™',
#  2128: 'Toca Kitchen 2',
#  2133: 'DC Super Hero Girls™',
#  2134: 'Strawberry Shortcake BerryRush',
#  2136: 'Disney Magic Kingdoms: Build Your Own Magical Park',
#  2152: 'Toca Life: City',
#  2185: 'Papumba Academy - Fun Learning For Kids',
#  2194: 'Kids Balloon Pop Game Free 🎈',
#  2195: 'Sounds for Toddlers FREE',
#  2196: 'Elmo Calls by Sesame Street',
#  2197: 'Sago Mini Friends',
#  2198: 'Papumba Academy - Fun Learning For Kids',
#  2199: 'Tee and Mo Bath Time Free',
#  2200: 'Bita and the Animals - Pelos Ares',
#  2201: 'TO-FU Oh!SUSHI',
#  2202: 'DreamWorks Friends',
#  2203: 'Avokiddo Emotions',
#  2204: 'Nighty Night Circus',
#  2205: 'Sago Mini Babies',
#  2206: "Dr. Panda & Toto's Treehouse",
#  2207: 'ROBLOX',
#  2208: 'PlayKids - Educational cartoons and games for kids',
#  2209: 'YouTube Kids',
#  2212: 'Baby Panda Care',
#  2215: 'Monster High™',
#  2217: 'Duolingo: Learn Languages Free',
#  2220: 'Shopkins World!',
#  2221: 'DisneyNOW – TV Shows & Games',
#  2223: 'Equestria Girls',
#  2226: 'Frozen Free Fall',
#  2227: 'Nick',
#  2228: 'Thomas & Friends: Race On!',
#  2230: 'Inside Out Thought Bubbles',
#  2233: 'Sago Mini Friends',
#  2235: 'School of Dragons',
#  2241: 'Peak – Brain Games & Training',
#  2345: 'Period Tracker',
#  2366: 'Vargo Anesthesia Mega App',
#  2367: 'Monash Uni Low FODMAP Diet',
#  2368: 'mySugr: the blood sugar tracker made just for you',
#  2373: 'Human Anatomy Atlas 2018: Complete 3D Human Body',
#  2379: 'ASCCP Mobile',
#  2381: 'Paramedic Protocol Provider',
#  2386: '2017 EMRA Antibiotic Guide',
#  2387: 'Essential Anatomy 3',
#  2388: 'EMT PASS',
#  2390: 'Block Buddy',
#  2396: 'EMT Review Plus',
#  2399: 'Journal Club: Medicine',
#  2400: 'Pedi STAT',
#  2401: 'AnatomyMapp',
#  2402: 'Diabetes & Diet Tracker',
#  2403: 'A Manual of Acupuncture',
#  2407: 'PTA Content Master',
#  2408: 'Muscle Premium - Human Anatomy, Kinesiology, Bones',
#  2410: 'Cardiac diagnosis (heart rate, arrhythmia)',
#  2417: 'Medical ID - In Case of Emergency (ICE)',
#  2419: 'IBM Micromedex Drug Info',
#  2420: 'Advanced Comprehension Therapy',
#  2421: 'Hospitalist Handbook',
#  2487: 'Teladoc Member',
#  2489: 'Ada - Your Health Guide',
#  2490: 'Ovia Fertility Tracker & Ovulation Calculator',
#  2494: 'Youper - AI Therapy',
#  2495: 'MoodSpace',
#  2496: 'Super Hearing Super Ear Amplifier',
#  2499: 'Penn State Health OnDemand',
#  2500: 'ScriptSave WellRx Rx Discounts',
#  2503: 'Free Blood Pressure',
#  2506: 'All Mental disorders',
#  2508: 'Nurse Grid',
#  2513: 'JH Blood Pressure Monitor',
#  2514: 'Blood Pressure',
#  2517: 'RT 516 VET',
#  2518: 'Anthem Anywhere',
#  2519: 'Sway Medical',
#  2522: "fred's Pharmacy",
#  2530: 'Breastfeeding Tracker Baby Log',
#  2538: 'Banfield Pet Health Tracker',
#  2544: '1800 Contacts - Lens Store',
#  2588: 'TextNow - free text + calls',
#  2600: 'Tumblr',
#  2604: 'Snapchat',
#  2605: 'Instagram',
#  2609: 'Periscope - Live Video',
#  2611: 'Snapchat',
#  2612: 'Instagram',
#  2613: 'Pinterest',
#  2618: 'MeetMe: Chat & Meet New People',
#  2619: 'ooVoo Video Calls, Messaging & Stories',
#  2622: 'LinkedIn',
#  2624: 'Tango - Live Video Broadcast',
#  2625: 'SayHi Chat, Meet New People',
#  2626: 'Tapatalk - 100,000+ Forums',
#  2628: 'Badoo - Free Chat & Dating App',
#  2629: 'Nextdoor - Local neighborhood news & classifieds',
#  2631: 'MeetMe: Chat & Meet New People',
#  2635: 'Meetup',
#  2636: 'Text Free: WiFi Calling App',
#  2638: 'textPlus: Free Text & Calls',
#  2642: 'Meetup',
#  2643: 'POF Free Dating App',
#  2644: 'MeetMe: Chat & Meet New People',
#  2645: 'Tagged - Meet, Chat & Dating',
#  2646: 'LOVOO',
#  2647: 'SKOUT - Meet, Chat, Go Live',
#  2648: 'Badoo - Free Chat & Dating App',
#  2649: 'Jaumo Dating, Flirt & Live Video',
#  2651: 'SayHi Chat, Meet New People',
#  2653: 'Couple - Relationship App',
#  2654: 'Meetup',
#  2713: 'Wish - Shopping Made Fun',
#  2724: 'SnipSnap Coupon App',
#  2725: 'Extreme Coupon Finder',
#  2726: 'Checkout 51: Grocery coupons',
#  2727: 'The Coupons App',
#  2732: 'RetailMeNot - Coupons, Deals & Discount Shopping',
#  2733: 'Groupon - Shop Deals, Discounts & Coupons',
#  2735: 'Stocard - Rewards Cards Wallet',
#  2738: 'Extreme Coupon Finder',
#  2739: 'eBay: Buy & Sell this Summer - Discover Deals Now!',
#  2740: 'Checkout 51: Grocery coupons',
#  2744: 'Gyft - Mobile Gift Card Wallet',
#  2746: 'Shopkick: Free Gift Cards, Shop Rewards & Deals',
#  2748: 'The Coupons App',
#  2749: 'Shopular: Coupons, Weekly Ads & Shopping Deals',
#  2750: 'Wish - Shopping Made Fun',
#  2751: 'Carousell: Snap-Sell, Chat-Buy',
#  2753: 'Walmart',
#  2756: 'Ibotta: Cash Back Savings, Rewards & Coupons App',
#  2757: 'AliExpress - Smarter Shopping, Better Living',
#  2758: 'LivingSocial - Local Deals',
#  2764: 'Amazon Shopping',
#  2768: 'RetailMeNot - Coupons, Deals & Discount Shopping',
#  2770: 'Poshmark - Buy & Sell Fashion',
#  2771: 'Target - now with Cartwheel',
#  2774: 'ZALORA Fashion Shopping',
#  2775: 'eBay: Buy & Sell this Summer - Discover Deals Now!',
#  2776: 'Fancy',
#  2777: "Modcloth – Unique Indie Women's Fashion & Style",
#  2778: 'Gyft - Mobile Gift Card Wallet',
#  2779: "JackThreads: Men's Shopping",
#  2780: 'LivingSocial - Local Deals',
#  2781: 'Zappos – Shoe shopping made simple',
#  2782: 'Wanelo Shopping',
#  2783: 'Etsy: Handmade & Vintage Goods',
#  2784: 'Groupon - Shop Deals, Discounts & Coupons',
#  2785: 'eBay: Buy & Sell this Summer - Discover Deals Now!',
#  2790: "JackThreads: Men's Shopping",
#  2791: 'AliExpress - Smarter Shopping, Better Living',
#  2794: 'Slickdeals: Coupons & Shopping',
#  2795: 'Target - now with Cartwheel',
#  2797: 'Wish - Shopping Made Fun',
#  2798: 'Fancy',
#  2801: 'ASOS',
#  2854: 'Google Photos',
#  2858: 'Shutterfly: Free Prints, Photo Books, Cards, Gifts',
#  2859: 'InstaBeauty -Makeup Selfie Cam',
#  2860: 'B612 - Beauty & Filter Camera',
#  2863: 'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  2868: 'YouCam Perfect - Selfie Photo Editor',
#  2885: 'Google Photos',
#  2886: 'Muzy - Share photos & collages',
#  2887: 'QuickPic - Photo Gallery with Google Drive Support',
#  2888: 'Flickr',
#  2889: 'Shutterfly: Free Prints, Photo Books, Cards, Gifts',
#  2899: 'Open Camera',
#  2900: 'Camera for Android',
#  2905: 'Cymera Camera- Photo Editor, Filter,Collage,Layout',
#  2910: 'Candy Camera - selfie, beauty camera, photo editor',
#  2912: 'Camera360: Selfie Photo Editor with Funny Sticker',
#  2913: 'Facetune - For Free',
#  2917: 'Photo Editor Selfie Camera Filter & Mirror Image',
#  2920: 'HD Camera for Android',
#  2922: 'Photo Editor Pro',
#  2923: 'YouCam Makeup - Magic Selfie Makeovers',
#  2925: 'Photo Editor-',
#  2926: 'Camera for Android',
#  2934: 'Photo Editor',
#  2936: 'Cymera Camera- Photo Editor, Filter,Collage,Layout',
#  2937: 'Adobe Photoshop Express:Photo Editor Collage Maker',
#  2938: 'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  2942: 'InstaSize Photo Filters & Collage Editor',
#  2945: 'Candy Camera - selfie, beauty camera, photo editor',
#  2946: 'YouCam Perfect - Selfie Photo Editor',
#  2950: 'Camera360: Selfie Photo Editor with Funny Sticker',
#  2951: 'Facetune - For Free',
#  2956: 'Shutterfly: Free Prints, Photo Books, Cards, Gifts',
#  2958: 'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  3008: 'CBS Sports App - Scores, News, Stats & Watch Live',
#  3010: 'Yahoo Fantasy Sports - #1 Rated Fantasy App',
#  3011: 'ESPN',
#  3012: 'NFL',
#  3013: 'Bleacher Report: sports news, scores, & highlights',
#  3014: 'ESPN Fantasy Sports',
#  3015: 'theScore: Live Sports Scores, News, Stats & Videos',
#  3016: 'CBS Sports App - Scores, News, Stats & Watch Live',
#  3019: 'ESPN',
#  3020: 'MLB At Bat',
#  3021: 'CBS Sports App - Scores, News, Stats & Watch Live',
#  3023: 'WatchESPN',
#  3038: 'Hole19: Golf GPS App, Rangefinder & Scorecard',
#  3043: 'Yahoo Fantasy Sports - #1 Rated Fantasy App',
#  3046: 'ESPN Fantasy Sports',
#  3048: 'CBS Sports Fantasy',
#  3049: 'ESPN',
#  3051: 'Bleacher Report: sports news, scores, & highlights',
#  3056: 'theScore: Live Sports Scores, News, Stats & Videos',
#  3057: 'CBS Sports App - Scores, News, Stats & Watch Live',
#  3061: 'ESPN',
#  3062: 'Bleacher Report: sports news, scores, & highlights',
#  3063: 'MLB At Bat',
#  3064: 'theScore: Live Sports Scores, News, Stats & Videos',
#  3065: 'CBS Sports App - Scores, News, Stats & Watch Live',
#  3067: 'Yahoo Sports - scores, stats, news, & highlights',
#  3068: 'WatchESPN',
#  3070: 'FotMob - Live Soccer Scores',
#  3072: 'Yahoo Fantasy Sports - #1 Rated Fantasy App',
#  3073: 'ESPN',
#  3075: 'NFL',
#  3080: 'US Open Tennis Championships 2018',
#  3081: 'Bleacher Report: sports news, scores, & highlights',
#  3082: 'MLB At Bat',
#  3083: 'FIFA - Tournaments, Soccer News & Live Scores',
#  3086: 'theScore: Live Sports Scores, News, Stats & Videos',
#  3089: 'Golfshot: Golf GPS + Tee Times',
#  3090: 'BBC Sport',
#  3091: 'CBS Sports App - Scores, News, Stats & Watch Live',
#  3092: 'Yahoo Sports - scores, stats, news, & highlights',
#  3095: 'WatchESPN',
#  3096: 'MLB Ballpark',
#  3098: 'FOX Sports: Live Streaming, Scores & News',
#  3099: 'Fantasy Football',
#  3100: 'PGA TOUR',
#  3101: 'UFC',
#  3119: 'trivago: Hotels & Travel',
#  3130: 'Expedia Hotels, Flights & Car Rental Travel Deals',
#  3137: 'TripAdvisor Hotels Flights Restaurants Attractions',
#  3149: 'Skyscanner',
#  3157: 'Booking.com Travel Deals',
#  3171: 'TripAdvisor Hotels Flights Restaurants Attractions',
#  3174: 'Priceline Hotel Deals, Rental Cars & Flights',
#  3175: 'United Airlines',
#  3176: 'Expedia Hotels, Flights & Car Rental Travel Deals',
#  3180: 'Southwest Airlines',
#  3184: 'Hopper - Watch & Book Flights',
#  3186: 'Fly Delta',
#  3188: 'KAYAK Flights, Hotels & Cars',
#  3189: 'American Airlines',
#  3193: 'Skyscanner',
#  3201: 'Priceline Hotel Deals, Rental Cars & Flights',
#  3203: 'trivago: Hotels & Travel',
#  3204: 'Expedia Hotels, Flights & Car Rental Travel Deals',
#  3206: 'KAYAK Flights, Hotels & Cars',
#  3207: 'Orbitz - Hotels, Flights & Package Deals',
#  3208: 'Skyscanner',
#  3211: 'Hotels.com: Book Hotel Rooms & Find Vacation Deals',
#  3212: 'Booking.com Travel Deals',
#  3214: 'Hostelworld: Hostels & Cheap Hotels Travel App',
#  3215: 'TripAdvisor Hotels Flights Restaurants Attractions',
#  3216: 'Airbnb',
#  3222: 'Skyscanner',
#  3223: 'HotelTonight: Book amazing deals at great hotels',
#  3224: 'Maps - Navigate & Explore',
#  3233: 'Google Street View',
#  3243: 'Calculator',
#  3327: 'Gboard - the Google Keyboard',
#  3399: 'ZEDGE™ Ringtones & Wallpapers',
#  3425: 'ZEDGE™ Ringtones & Wallpapers',
#  3436: 'Nova Launcher',
#  3437: 'Apex Launcher',
#  3438: 'Smart Launcher 5',
#  3508: 'Google Keep',
#  3511: 'Evernote – Organizer, Planner for Notes & Memos',
#  3515: 'ES File Explorer File Manager',
#  3523: 'Microsoft Word',
#  3524: 'Google Drive',
#  3525: 'Adobe Acrobat Reader',
#  3526: 'Google PDF Viewer',
#  3528: 'Microsoft Excel',
#  3529: 'Google Docs',
#  3531: 'Microsoft PowerPoint',
#  3533: 'Microsoft OneNote',
#  3534: 'Google Calendar',
#  3546: 'Google Keep',
#  3547: 'Wunderlist: To-Do List & Tasks',
#  3548: 'Evernote – Organizer, Planner for Notes & Memos',
#  3549: 'Any.do: To-do list, Calendar, Reminders & Planner',
#  3550: 'Todoist: To-do lists for task management & errands',
#  3551: 'Microsoft OneNote',
#  3557: 'Planner Pro-Personal Organizer',
#  3563: 'Google Calendar',
#  3566: 'Google Drive',
#  3568: 'Microsoft OneDrive',
#  3570: 'Dropbox',
#  3712: 'MX Player',
#  3713: 'Video Editor',
#  3766: 'Google News',
#  3768: 'Flipboard: News For Our Time',
#  3781: 'BBC News',
#  3786: 'Fox News – Breaking News, Live Video & News Alerts',
#  3791: 'USA TODAY',
#  3793: 'CNN Breaking US & World News',
#  3797: 'Twitter',
#  3801: 'BBC News',
#  3802: 'NPR News',
#  3803: 'Fox News – Breaking News, Live Video & News Alerts',
#  3805: 'Haystack TV: Local & World News - Free',
#  3807: 'ABC News - US & World News',
#  3808: 'USA TODAY',
#  3809: 'NBC News',
#  3810: 'The Wall Street Journal: Business & Market News',
#  3812: 'CNN Breaking US & World News',
#  3815: 'NYTimes - Latest News',
#  3816: 'Newsroom: News Worth Sharing',
#  3817: 'Google News',
#  3819: 'BuzzFeed: News, Tasty, Quizzes',
#  3820: 'Flipboard: News For Our Time',
#  3871: 'Snapchat',
#  3872: 'Flashlight',
#  3880: 'Pou',
#  3881: 'Agar.io',
#  3884: 'Angry Birds Classic',
#  3889: 'My Talking Tom',
#  3890: 'Netflix',
#  3895: 'Bubble Shooter',
#  3896: 'Adobe Acrobat Reader',
#  3897: 'Subway Surfers',
#  3903: 'LEGO® Juniors Create & Cruise',
#  3905: 'WhatsApp Messenger',
#  3908: 'Google Translate',
#  3909: 'Pokémon GO',
#  3910: 'Instagram',
#  3911: 'My Talking Angela',
#  3912: 'YouTube Kids',
#  3914: 'PAC-MAN',
#  3916: 'Colorfy: Coloring Book for Adults - Free',
#  3921: 'Toca Kitchen 2',
#  3923: 'Amazon Shopping',
#  3927: 'Chick-fil-A',
#  3929: 'YouTube',
#  3931: 'Flow Free',
#  3935: 'Microsoft Word',
#  3937: "Alto's Adventure",
#  3941: 'Zombie Tsunami',
#  3944: 'Facebook',
#  3947: 'B612 - Beauty & Filter Camera',
#  3953: 'Block Craft 3D: Building Simulator Games For Free',
#  3954: '8 Ball Pool',
#  3957: 'VPN Free - Betternet Hotspot VPN & Private Browser',
#  3966: 'EMT Tutor NREMT-B Study Guide',
#  3971: 'EMT-B Pocket Prep',
#  3972: 'UC Browser - Fast Download Private & Secure',
#  3974: 'Hungry Shark Evolution',
#  3977: 'Diary with lock',
#  3987: 'Clash of Clans',
#  3988: 'Clash Royale',
#  3989: 'C Programming',
#  3990: 'CppDroid - C/C++ IDE',
#  3995: 'Candy Crush Saga',
#  3997: 'Google Chrome: Fast & Secure',
#  4000: 'Learn C++',
#  4018: 'Hill Climb Racing',
#  4032: 'ZEDGE™ Ringtones & Wallpapers',
#  4037: 'Minion Rush: Despicable Me Official Game',
#  4040: 'Google Duo - High Quality Video Calls',
#  4041: 'Crossy Road',
#  4042: 'Temple Run 2',
#  4049: 'Dropbox',
#  4052: 'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  4056: 'Plants vs. Zombies FREE',
#  4057: 'Dream League Soccer 2018',
#  4069: 'eBay: Buy & Sell this Summer - Discover Deals Now!',
#  4070: 'ESPN',
#  4073: 'ES File Explorer File Manager',
#  4075: 'Firefox Browser fast & private',
#  4076: 'E*TRADE Mobile',
#  4077: 'WWE',
#  4084: 'Amazon Kindle',
#  4085: 'Evernote – Organizer, Planner for Notes & Memos',
#  4087: 'Microsoft Edge',
#  4088: 'Microsoft Outlook',
#  4089: 'Pinterest',
#  4090: 'ClassDojo',
#  4091: 'The Coupons App',
#  4096: 'Ebook Reader',
#  4097: 'Gmail',
#  4099: 'Maps - Navigate & Explore',
#  4100: 'AliExpress - Smarter Shopping, Better Living',
#  4102: 'Flipkart Online Shopping App',
#  4103: 'Wish - Shopping Made Fun',
#  4105: 'Messenger – Text and Video Chat for Free',
#  4106: 'Facebook Lite',
#  4107: 'Messenger Lite: Free Calls & Messages',
#  4116: 'Twitter',
#  4123: 'LINE: Free Calls & Messages',
#  4124: 'imo beta free calls and text',
#  4142: 'Geometry Dash World',
#  4145: 'Google+',
#  4146: 'PUBG MOBILE',
#  4148: 'Gboard - the Google Keyboard',
#  4149: 'Granny',
#  4151: 'Google',
#  4154: 'Hangouts',
#  4161: 'G Cloud Backup',
#  4171: 'Google Drive',
#  4183: 'Helix Jump',
#  4186: 'H&M',
#  4201: 'H TV',
#  4212: 'Talking Ben the Dog',
#  4223: 'imo free video calls and chat',
#  4225: 'free video calls and chat',
#  4228: 'slither.io',
#  4233: 'POF Free Dating App',
#  4235: 'Skype - free IM & video calls',
#  4236: 'Sonic Dash',
#  4239: 'Text Free: WiFi Calling App',
#  4240: 'Talkatone: Free Texts, Calls & Phone Number',
#  4242: 'Textgram - write on photos',
#  4245: 'Zombie Catchers',
#  4250: 'Jetpack Joyride',
#  4253: 'Anger of stick 5 : zombie',
#  4258: 'Cut the Rope FULL FREE',
#  4262: 'Turbo FAST',
#  4288: 'K PLUS',
#  4301: 'PowerDirector Video Editor App: 4K, Slow Mo & More',
#  4302: 'Fuzzy Numbers: Pre-K Number Foundation',
#  4303: 'KakaoTalk: Free Calls & Text',
#  4321: 'LiveMe - Video chat, new friends, and make money',
#  4322: 'Talking Tom Gold Run',
#  4323: 'letgo: Buy & Sell Used Stuff, Cars & Real Estate',
#  4326: 'Love Balls',
#  4328: 'Last Day on Earth: Survival',
#  4348: 'Minecraft',
#  4356: 'MEGA',
#  4366: 'MX Player',
#  4369: 'I’m Expecting - Pregnancy App',
#  4375: 'Diabetes:M',
#  4422: 'Opera Mini - fast web browser',
#  4423: 'Opera Browser: Fast and Secure',
#  4442: 'O-Star',
#  4449: 'PicsArt Photo Studio: Collage Maker & Pic Editor',
#  4502: 'Quora',
#  4528: 'ROBLOX',
#  4567: 'SHAREit - Transfer & Share',
#  4587: 'Tumblr',
#  4589: 'Topbuzz: Breaking News, Videos & Funny GIFs',
#  4590: 'Twitch: Livestream Multiplayer Games & Esports',
#  4593: 'Telegram',
#  4594: 'myAT&T',
#  4603: 'Truecaller: Caller ID, SMS spam blocking & Dialer',
#  4611: 'Showtime Anytime',
#  4634: 'UC Browser Mini -Tiny Fast Private & Secure',
#  4635: 'Uber',
#  4677: 'Viber Messenger',
#  4682: 'VLC for Android',
#  4687: 'Vigo Video',
#  4713: 'WeChat',
#  4716: 'Wattpad 📖 Free Books',
#  4718: 'Waze - GPS, Maps, Traffic Alerts & Live Navigation',
#  4719: 'Dating App, Flirt & Chat : W-Match',
#  4721: 'WPS Office - Word, Docs, PDF, Note, Slide & Sheet',
#  4725: 'LINE WEBTOON - Free Comics',
#  4728: 'WhatsApp Business',
#  4743: 'We Heart It',
#  4745: 'TripAdvisor Hotels Flights Restaurants Attractions',
#  4748: 'Telegram X',
#  4749: 'Share Music & Transfer Files - Xender',
#  4794: 'Yandex Browser with Protect',
#  4797: 'YouTube Studio',
#  4801: 'Yahoo Mail – Stay Organized',
#  4805: 'PBS KIDS Video',
#  4806: 'YouTube Gaming',
#  4810: 'GO Keyboard - Emoticon keyboard, Free Theme, GIF',
#  4822: 'Zello PTT Walkie Talkie',
#  4825: 'Z Camera - Photo Editor, Beauty Selfie, Collage',
#  4855: 'Six Pack in 30 Days - Abs Workout',
#  4865: 'Angry Birds 2',
#  4870: 'Angry Birds Rio',
#  4929: 'AC - Tips & News for Android™',
#  4950: 'CM Browser - Ad Blocker , Fast Download , Privacy',
#  4980: 'Google Ads',
#  4988: 'Mobi Calculator free & AD free!',
#  4990: 'Flipp - Weekly Shopping',
#  4992: 'A&E - Watch Full Episodes of TV Shows',
#  5043: 'Camera FV-5 Lite',
#  5045: 'Cardiac diagnosis (heart rate, arrhythmia)',
#  5063: 'Open Camera',
#  5076: 'All Football - Latest News & Videos',
#  5148: 'Maricopa AH',
#  5190: 'Youper - AI Therapy',
#  5224: 'Animal Jam - Play Wild!',
#  5295: 'RULES OF SURVIVAL',
#  5354: 'Amazon for Tablets',
#  5382: 'Final Fantasy XV: A New Empire',
#  5385: 'The Sims™ FreePlay',
#  5393: 'Text free - Free Text + Call',
#  5396: 'Google Photos',
#  5416: '365Scores - Live Scores',
#  5434: 'DINO HUNTER: DEADLY SHORES',
#  5449: 'AP Mobile - Breaking News',
#  5475: 'Reuters News',
#  5506: 'Puffin Web Browser',
#  5513: 'AccuWeather: Daily Forecast & Live Weather Reports',
#  5517: 'Moovit: Bus Time & Train Time Live Info',
#  5532: 'Jurassic World™ Alive',
#  5538: 'Houzz Interior Design Ideas',
#  5545: 'NYTimes - Latest News',
#  5546: 'Overstock – Home Decor, Furniture Shopping',
#  5595: 'Google Voice',
#  5596: 'Choices: Stories You Play',
#  5601: 'Runtastic Sleep Better: Sleep Cycle & Smart Alarm',
#  5602: 'Google Pay',
#  5607: 'Ringtone Maker',
#  5610: 'Google Allo',
#  5611: 'Plants vs. Zombies™ Heroes',
#  5612: 'CM FILE MANAGER HD',
#  5621: 'MLB At Bat',
#  5624: 'HotelTonight: Book amazing deals at great hotels',
#  5665: 'realestate.com.au - Buy, Rent & Sell Property',
#  5705: 'Video Player All Format',
#  5729: 'DEER HUNTER 2018',
#  5775: 'Video Editor',
#  5857: 'Google Play Games',
#  5864: 'ai.type Free Emoji Keyboard',
#  5906: 'Manga AZ - Manga Comic Reader',
#  5911: 'British Airways',
#  5953: 'American Airlines',
#  5959: 'Anthem BC Anywhere',
#  5965: 'Transit: Real-Time Transit App',
#  5990: 'PMHNP-BC Pocket Prep',
#  6055: 'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  6078: 'Bowmasters',
#  6087: 'Nick',
#  6195: 'mySugr: the blood sugar tracker made just for you',
#  6204: 'Backgrounds HD (Wallpapers)',
#  6213: 'Blur Image Background',
#  6252: 'Newegg Mobile',
#  ...}

# %%
d_hash = {}
lst = []
dupe_android = []
i = 1
for row in android[1:]:
    arr_string = ''.join(row)
    hasher = hash(arr_string)
    if hasher not in lst:
        lst.append(hasher)
        dupe_android.append(row)

# %%
explore_data(dupe_android,0,5)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']

# %%
reviews_max = {}

for app in dupe_android:
    name = app[0]
    n_reviews = float(app[3])
    
    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
        
    elif name not in reviews_max:
        reviews_max[name] = n_reviews

# %%
android_clean = []
already_added = []

for app in dupe_android:
    name = app[0]
    n_reviews = float(app[3])
    
    if (reviews_max[name] == n_reviews) and (name not in already_added):
        android_clean.append(app)
        already_added.append(name) # make sure this is inside the if block

# %% [markdown]
# 3. Removed non-English apps

# %%
def is_english(string):
    non_ascii = 0
    
    for character in string:
        if ord(character) > 127:
            non_ascii += 1
    
    if non_ascii > 3:
        return False
    else:
        return True

# %%
android_english = []
ios_english = []

for app in android_clean:
    name = app[0]
    if is_english(name):
        android_english.append(app)
        
for app in ios:
    name = app[1]
    if is_english(name):
        ios_english.append(app)
        
explore_data(android_english, 0, 3, True)
print('\n')
explore_data(ios_english, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# Number of rows: 6184
# Number of columns: 16
